# %% [markdown]
# # Proximal Policy Optimization (PPO) Tutorial

# %% [markdown]
# ## 1. Environment Preparation

# %% [markdown]
# ### 1.1 Download Packages for BipedalWalker-v3

# %%
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1
# !pip install colabgymrender==1.0.2
# !pip install swig
# !pip install box2d-py
# !pip install 'gym[Box2D]'
# Out:
# Requirement already satisfied: colabgymrender==1.0.2 in /usr/local/lib/python3.10/dist-packages (1.0.2)
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.10/dist-packages (from colabgymrender==1.0.2) (3.0)
# Requirement already satisfied: moviepy in /usr/local/lib/python3.10/dist-packages (from colabgymrender==1.0.2) (1.0.3)
# Requirement already satisfied: gym in /usr/local/lib/python3.10/dist-packages (from colabgymrender==1.0.2) (0.25.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from colabgymrender==1.0.2) (4.7.0.72)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym->colabgymrender==1.0.2) (1.22.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym->colabgymrender==1.0.2) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym->colabgymrender==1.0.2) (0.0.8)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender==1.0.2) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender==1.0.2) (4.65.0)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender==1.0.2) (2.27.1)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender==1.0.2) (0.1.10)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender==1.0.2) (2.25.1)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender==1.0.2) (0.4.8)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio<3.0,>=2.5->moviepy->colabgymrender==1.0.2) (8.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy->colabgymrender==1.0.2) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy->colabgymrender==1.0.2) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy->colabgymrender==1.0.2) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy->colabgymrender==1.0.2) (3.4)
# Requirement already satisfied: swig in /usr/local/lib/python3.10/dist-packages (4.1.1)
# Requirement already satisfied: box2d-py in /usr/local/lib/python3.10/dist-packages (2.3.5)
# Requirement already satisfied: gym[Box2D] in /usr/local/lib/python3.10/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym[Box2D]) (1.22.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym[Box2D]) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym[Box2D]) (0.0.8)
# Requirement already satisfied: box2d-py==2.3.5 in /usr/local/lib/python3.10/dist-packages (from gym[Box2D]) (2.3.5)
# Requirement already satisfied: pygame==2.1.0 in /usr/local/lib/python3.10/dist-packages (from gym[Box2D]) (2.1.0)
# Requirement already satisfied: swig==4.* in /usr/local/lib/python3.10/dist-packages (from gym[Box2D]) (4.1.1)

# %% [markdown]
# ### 1.2 Mount Drive and Set Project Path

# %%
from google.colab import drive
drive.mount('/content/drive')

import sys
project_root = '/content/drive/My Drive/ppo_tutorial/'
sys.path.append(project_root)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### 1.3 Test the BipedalWalker-v3 Environment

# %%
import os
import gym
import torch
import torch.nn as nn
import numpy as np
from colabgymrender.recorder import Recorder

env = gym.make('BipedalWalker-v3')
s_dim = env.observation_space.shape[0]
a_dim = env.action_space.shape[0]
print(s_dim)
print(a_dim)
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# 24
# 4

# %% [markdown]
# ## 2. Policy Network & Value Network Construction

# %% [markdown]
# ### 2.1 Diagonal Gaussian Distribution Module

# %%
#AddBias module
class AddBias(nn.Module):
    def __init__(self, bias):
        super(AddBias, self).__init__()
        self._bias = nn.Parameter(bias.unsqueeze(1))

    def forward(self, x):
        bias = self._bias.t().view(1, -1)
        return x + bias

#Gaussian distribution with given mean & std.
class FixedNormal(torch.distributions.Normal):
    def log_probs(self, x):
        return super().log_prob(x).sum(-1)

    def entropy(self):
        return super().entropy().sum(-1)

    def mode(self):
        return self.mean

#Diagonal Gaussian module
class DiagGaussian(nn.Module):
    def __init__(self, inp_dim, out_dim):
        super(DiagGaussian, self).__init__()
        self.fc_mean = nn.Linear(inp_dim, out_dim)
        self.b_logstd = AddBias(torch.zeros(out_dim))

    def forward(self, x):
        mean = self.fc_mean(x)
        logstd = self.b_logstd(torch.zeros_like(mean))
        return FixedNormal(mean, logstd.exp())

# %% [markdown]
# ### 2.2 Policy Network & Value Network Module

# %%
#Policy Network
class PolicyNet(nn.Module):
    #Constructor
    def __init__(self, s_dim, a_dim):
        super(PolicyNet, self).__init__()
        #TODO(Lab-1): Policy Network Architecture
        self.main = nn.Sequential(
            nn.Linear(s_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU()
        )
        self.dist = DiagGaussian(128, a_dim)

    #Forward pass
    def forward(self, state, deterministic=False):
        feature = self.main(state)
        dist = self.dist(feature)

        if deterministic:
            action = dist.mode()
        else:
            action = dist.sample()

        return action, dist.log_probs(action)

    #Choose an action (stochastically or deterministically)
    def choose_action(self, state, deterministic=False):
        feature = self.main(state)
        dist = self.dist(feature)

        if deterministic:
            return dist.mode()

        return dist.sample()

    #Evaluate a state-action pair (output log-prob. & entropy)
    def evaluate(self, state, action):
        feature = self.main(state)
        dist = self.dist(feature)
        return dist.log_probs(action), dist.entropy()

#Value Network
class ValueNet(nn.Module):
    #Constructor
    def __init__(self, s_dim):
        super(ValueNet, self).__init__()
        #TODO(Lab-2): Value Network Architecture
        self.main = nn.Sequential(
            nn.Linear(s_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, 1)
        )
    #Forward pass
    def forward(self, state):
        return self.main(state)[:, 0]

# %% [markdown]
# ### 2.3 Create Policy Network & Value Network

# %%
policy_net = PolicyNet(s_dim, a_dim)
value_net = ValueNet(s_dim)
print(policy_net)
print(value_net)
# Out:
# PolicyNet(
#   (main): Sequential(
#     (0): Linear(in_features=24, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=128, bias=True)
#     (3): ReLU()
#   )
#   (dist): DiagGaussian(
#     (fc_mean): Linear(in_features=128, out_features=4, bias=True)
#     (b_logstd): AddBias()
#   )
# )
# ValueNet(
#   (main): Sequential(
#     (0): Linear(in_features=24, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=128, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# ## 3. Environment Runner Construction

# %% [markdown]
# ### 3.1 EnvRunner Class

# %%
class EnvRunner:
    #Constructor
    def __init__(self, s_dim, a_dim, gamma=0.99, lamb=0.95, max_step=2048, device='cpu'):
        self.s_dim = s_dim
        self.a_dim = a_dim
        self.gamma = gamma
        self.lamb = lamb
        self.max_step = max_step
        self.device = device

        #Storages (state, action, value, reward, a_logp)
        self.mb_states = np.zeros((self.max_step, self.s_dim), dtype=np.float32)
        self.mb_actions = np.zeros((self.max_step, self.a_dim), dtype=np.float32)
        self.mb_values = np.zeros((self.max_step,), dtype=np.float32)
        self.mb_rewards = np.zeros((self.max_step,), dtype=np.float32)
        self.mb_a_logps = np.zeros((self.max_step,), dtype=np.float32)

    #Compute discounted return
    def compute_discounted_return(self, rewards, last_value):
        #TODO(Lab-3): Compute discounted return
        returns = np.zeros_like(rewards)
        n_step = len(rewards)

        for t in reversed(range(n_step)):
            if t == n_step - 1:
                returns[t] = rewards[t] + self.gamma * last_value
            else:
                returns[t] = rewards[t] + self.gamma * returns[t+1]

        return returns

    #Compute generalized advantage estimation (Optional)
    def compute_gae(self, rewards, values, last_value):
        advs = np.zeros_like(rewards)
        n_step = len(rewards)
        last_gae_lam = 0.0

        for t in reversed(range(n_step)):
            if t == n_step - 1:
                next_value = last_value
            else:
                next_value = values[t+1]

            delta = rewards[t] + self.gamma*next_value - values[t]
            advs[t] = last_gae_lam = delta + self.gamma*self.lamb*last_gae_lam

        return advs + values

    #Run an episode using the policy net & value net
    def run(self, env, policy_net, value_net):
        #TODO(Lab-4): Run an episode to collect data
        state = env.reset()   #Initial state
        episode_len = self.max_step

        for step in range(self.max_step):
            state_tensor = torch.tensor(np.expand_dims(state, axis=0), dtype=torch.float32, device=self.device)
            action, a_logp = policy_net(state_tensor)
            value = value_net(state_tensor)

            action = action.cpu().numpy()[0]
            a_logp = a_logp.cpu().numpy()
            value  = value.cpu().numpy()

            self.mb_states[step] = state
            self.mb_actions[step] = action
            self.mb_a_logps[step] = a_logp
            self.mb_values[step] = value

            state, reward, done, info = env.step(action)
            self.mb_rewards[step] = reward

            if done:
                episode_len = step + 1
                break
        #Compute returns
        last_value = value_net(
            torch.tensor(np.expand_dims(state, axis=0), dtype=torch.float32, device=self.device)
        ).cpu().numpy()

        mb_returns = self.compute_discounted_return(self.mb_rewards[:episode_len], last_value)
        '''
        mb_returns = self.compute_gae(
            self.mb_rewards[:episode_len],
            self.mb_values[:episode_len],
            last_value
        )
        '''
        return self.mb_states[:episode_len], \
                self.mb_actions[:episode_len], \
                self.mb_a_logps[:episode_len], \
                self.mb_values[:episode_len], \
                mb_returns, \
                self.mb_rewards[:episode_len]

# %% [markdown]
# ### 3.2 Create EnvRunner

# %%
runner = EnvRunner(s_dim, a_dim)

# %% [markdown]
# ## 4. PPO Algorithm

# %% [markdown]
# ### 4.1 PPO Class

# %%
class PPO:
    #Constructor
    def __init__(self, policy_net, value_net, lr=1e-4, max_grad_norm=0.5, ent_weight=0.01, clip_val=0.2, sample_n_epoch=4, sample_mb_size=64, device='cpu'):
        self.policy_net = policy_net
        self.value_net = value_net
        self.max_grad_norm = max_grad_norm
        self.ent_weight = ent_weight
        self.clip_val = clip_val
        self.sample_n_epoch = sample_n_epoch
        self.sample_mb_size = sample_mb_size
        self.device = device
        self.opt_polcy = torch.optim.Adam(policy_net.parameters(), lr)
        self.opt_value = torch.optim.Adam(value_net.parameters(), lr)

    #Train the policy net & value net using PPO
    def train(self, mb_states, mb_actions, mb_old_values, mb_advs, mb_returns, mb_old_a_logps):
        #Convert numpy array to tensor
        mb_states = torch.from_numpy(mb_states).to(self.device)
        mb_actions = torch.from_numpy(mb_actions).to(self.device)
        mb_old_values = torch.from_numpy(mb_old_values).to(self.device)
        mb_advs = torch.from_numpy(mb_advs).to(self.device)
        mb_returns = torch.from_numpy(mb_returns).to(self.device)
        mb_old_a_logps = torch.from_numpy(mb_old_a_logps).to(self.device)
        episode_length = len(mb_states)
        rand_idx = np.arange(episode_length)
        sample_n_mb = episode_length // self.sample_mb_size

        if sample_n_mb <= 0:
            sample_mb_size = episode_length
            sample_n_mb = 1
        else:
            sample_mb_size = self.sample_mb_size

        for i in range(self.sample_n_epoch):
            np.random.shuffle(rand_idx)

            for j in range(sample_n_mb):
                #Randomly sample a batch for training
                sample_idx = rand_idx[j*sample_mb_size : (j+1)*sample_mb_size]
                sample_states = mb_states[sample_idx]
                sample_actions = mb_actions[sample_idx]
                sample_old_values = mb_old_values[sample_idx]
                sample_advs = mb_advs[sample_idx]
                sample_returns = mb_returns[sample_idx]
                sample_old_a_logps = mb_old_a_logps[sample_idx]

                sample_a_logps, sample_ents = self.policy_net.evaluate(sample_states, sample_actions)
                sample_values = self.value_net(sample_states)
                ent = sample_ents.mean()

                #TODO(Lab-5): Compute value loss & policy gradient loss
                v_pred_clip = sample_old_values + torch.clamp(sample_values - sample_old_values, -self.clip_val, self.clip_val)
                v_loss1 = (sample_returns - sample_values).pow(2)
                v_loss2 = (sample_returns - v_pred_clip).pow(2)
                v_loss = torch.max(v_loss1, v_loss2).mean()


                ratio = (sample_a_logps - sample_old_a_logps).exp()
                pg_loss1 = -sample_advs * ratio
                pg_loss2 = -sample_advs * torch.clamp(ratio, 1.0-self.clip_val, 1.0+self.clip_val)
                pg_loss = torch.max(pg_loss1, pg_loss2).mean() - self.ent_weight*ent

                #Train actor
                self.opt_polcy.zero_grad()
                pg_loss.backward()
                nn.utils.clip_grad_norm_(self.policy_net.parameters(), self.max_grad_norm)
                self.opt_polcy.step()

                #Train critic
                self.opt_value.zero_grad()
                v_loss.backward()
                nn.utils.clip_grad_norm_(self.value_net.parameters(), self.max_grad_norm)
                self.opt_value.step()

        return pg_loss.item(), v_loss.item(), ent.item()

# %% [markdown]
# ### 4.2 Create PPO Agent

# %%
agent = PPO(policy_net, value_net)

# %% [markdown]
# ## 5. Training and Testing Process

# %% [markdown]
# ### 5.1 Play an Episode for Evaluation

# %%
def play(policy_net):
    render_env = Recorder(gym.make('BipedalWalker-v3'), project_root + 'video')

    with torch.no_grad():
        #TODO(Lab-6): Play an episode and evaluate the performance
        state = render_env.reset()
        total_reward = 0
        length = 0

        while True:
            state_tensor = torch.tensor(np.expand_dims(state, axis=0), dtype=torch.float32, device='cpu')
            action = policy_net.choose_action(state_tensor, deterministic=True).cpu().numpy()
            state, reward, done, info = render_env.step(action[0])
            total_reward += reward
            length += 1

            if done:
                print("[Evaluation] Total reward = {:.6f}, length = {:d}".format(total_reward, length), flush=True)
                break

    render_env.play()
    render_env.close()

# %%
play(policy_net)
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# [Evaluation] Total reward = -93.606786, length = 110
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4

# %% [markdown]
# ### 5.2 Train the Networks using PPO

# %%
def train(env, runner, policy_net, value_net, agent, max_episode=5000):
    mean_total_reward = 0
    mean_length = 0
    save_dir = project_root + '/save'

    if not os.path.exists(save_dir):
        os.mkdir(save_dir)

    for i in range(max_episode):
        #TODO(Lab-7): Run an episode to collect data and then train the model
        with torch.no_grad():
            mb_states, mb_actions, mb_old_a_logps, mb_values, mb_returns, mb_rewards = runner.run(env, policy_net, value_net)
            mb_advs = mb_returns - mb_values
            mb_advs = (mb_advs - mb_advs.mean()) / (mb_advs.std() + 1e-6)

        pg_loss, v_loss, ent = agent.train(mb_states, mb_actions, mb_values, mb_advs, mb_returns, mb_old_a_logps)
        mean_total_reward += mb_rewards.sum()
        mean_length += len(mb_states)
        print("[Episode {:4d}] total reward = {:.6f}, length = {:d}".format(i, mb_rewards.sum(), len(mb_states)))
        #Show the current result & save the model
        if i % 200 == 0:
            print("\n[{:5d} / {:5d}]".format(i, max_episode))
            print("----------------------------------")
            print("actor loss = {:.6f}".format(pg_loss))
            print("critic loss = {:.6f}".format(v_loss))
            print("entropy = {:.6f}".format(ent))
            print("mean return = {:.6f}".format(mean_total_reward / 200))
            print("mean length = {:.2f}".format(mean_length / 200))
            print("\nSaving the model ... ", end="")
            torch.save({
                "it": i,
                "PolicyNet": policy_net.state_dict(),
                "ValueNet": value_net.state_dict()
            }, os.path.join(save_dir, "model.pt"))
            print("Done.")
            print()
            play(policy_net)
            mean_total_reward = 0
            mean_length = 0
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
train(env, runner, policy_net, value_net, agent)
env.close()
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# [Episode    0] total reward = -103.598045, length = 72
#
# [    0 /  5000]
# ----------------------------------
# actor loss = -0.074274
# critic loss = 5421.066895
# entropy = 5.676342
# mean return = -0.517990
# mean length = 0.36
#
# Saving the model ... Done.
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# [Evaluation] Total reward = -93.455244, length = 111
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# [Episode    1] total reward = -118.160950, length = 63
# [Episode    2] total reward = -117.706200, length = 72
# [Episode    3] total reward = -116.483932, length = 77
# [Episode    4] total reward = -117.556396, length = 1600
# [Episode    5] total reward = -122.286667, length = 89
# [Episode    6] total reward = -99.642181, length = 81
# [Episode    7] total reward = -120.423820, length = 1600
# [Episode    8] total reward = -100.709152, length = 84
# [Episode    9] total reward = -131.500320, length = 104
# [Episode   10] total reward = -103.816338, length = 46
# [Episode   11] total reward = -126.600876, length = 1600
# [Episode   12] total reward = -104.180794, length = 43
# [Episode   13] total reward = -103.128967, length = 75
# [Episode   14] total reward = -126.965851, length = 1600
# [Episode   15] total reward = -115.601425, length = 1600
# [Episode   16] total reward = -124.467926, length = 1600
# [Episode   17] total reward = -119.188805, length = 114
# [Episode   18] total reward = -126.889137, length = 111
# [Episode   19] total reward = -120.699043, length = 67
# [Episode   20] total reward = -116.936417, length = 69
# [Episode   21] total reward = -100.597473, length = 69
# [Episode   22] total reward = -105.140503, length = 53
# [Episode   23] total reward = -102.219681, length = 70
# [Episode   24] total reward = -115.271355, length = 66
# [Episode   25] total reward = -116.223801, length = 1600
# [Episode   26] total reward = -101.381264, length = 52
# [Episode   27] total reward = -105.791603, length = 79
# [Episode   28] total reward = -103.292511, length = 59
# [Episode   29] total reward = -119.760834, length = 75
# [Episode   30] total reward = -137.085434, length = 272
# [Episode   31] total reward = -102.784058, length = 58
# [Episode   32] total reward = -117.570961, length = 59
# [Episode   33] total reward = -102.626297, length = 75
# [Episode   34] total reward = -105.872543, length = 73
# [Episode   35] total reward = -118.719940, length = 107
# [Episode   36] total reward = -101.229233, length = 77
# [Episode   37] total reward = -104.601219, length = 53
# [Episode   38] total reward = -112.646065, length = 59
# [Episode   39] total reward = -101.963501, length = 61
# [Episode   40] total reward = -102.190506, length = 59
# [Episode   41] total reward = -99.001213, length = 81
# [Episode   42] total reward = -102.968262, length = 50
# [Episode   43] total reward = -105.200371, length = 63
# [Episode   44] total reward = -105.314575, length = 129
# [Episode   45] total reward = -100.558151, length = 85
# [Episode   46] total reward = -121.116928, length = 75
# [Episode   47] total reward = -113.122559, length = 234
# [Episode   48] total reward = -103.233574, length = 69
# [Episode   49] total reward = -103.544533, length = 61
# [Episode   50] total reward = -98.990860, length = 68
# [Episode   51] total reward = -100.900002, length = 91
# [Episode   52] total reward = -195.301025, length = 1351
# [Episode   53] total reward = -102.592995, length = 61
# [Episode   54] total reward = -102.231583, length = 55
# [Episode   55] total reward = -116.629028, length = 79
# [Episode   56] total reward = -125.815735, length = 1600
# [Episode   57] total reward = -126.842026, length = 1600
# [Episode   58] total reward = -118.301643, length = 503
# [Episode   59] total reward = -126.952614, length = 101
# [Episode   60] total reward = -108.247719, length = 80
# [Episode   61] total reward = -121.861938, length = 83
# [Episode   62] total reward = -118.133682, length = 1600
# [Episode   63] total reward = -100.418495, length = 85
# [Episode   64] total reward = -99.642395, length = 67
# [Episode   65] total reward = -102.021172, length = 47
# [Episode   66] total reward = -102.427414, length = 82
# [Episode   67] total reward = -114.020683, length = 79
# [Episode   68] total reward = -120.721573, length = 83
# [Episode   69] total reward = -113.759766, length = 54
# [Episode   70] total reward = -112.452240, length = 1600
# [Episode   71] total reward = -110.945282, length = 1600
# [Episode   72] total reward = -108.043686, length = 70
# [Episode   73] total reward = -114.999939, length = 1600
# [Episode   74] total reward = -103.243759, length = 71
# [Episode   75] total reward = -107.084503, length = 1600
# [Episode   76] total reward = -121.175797, length = 58
# [Episode   77] total reward = -110.545021, length = 43
# [Episode   78] total reward = -100.928886, length = 83
# [Episode   79] total reward = -104.184509, length = 1600
# [Episode   80] total reward = -100.423759, length = 1600
# [Episode   81] total reward = -121.292740, length = 108
# [Episode   82] total reward = -107.213982, length = 1600
# [Episode   83] total reward = -111.707672, length = 90
# [Episode   84] total reward = -107.603065, length = 50
# [Episode   85] total reward = -126.190186, length = 141
# [Episode   86] total reward = -94.412857, length = 1600
# [Episode   87] total reward = -85.116760, length = 1600
# [Episode   88] total reward = -89.382744, length = 1600
# [Episode   89] total reward = -85.149895, length = 1600
# [Episode   90] total reward = -84.928482, length = 1600
# [Episode   91] total reward = -65.950333, length = 1600
# [Episode   92] total reward = -67.538483, length = 1600
# [Episode   93] total reward = -67.925385, length = 1600
# [Episode   94] total reward = -76.073227, length = 1600
# [Episode   95] total reward = -65.150169, length = 1600
# [Episode   96] total reward = -106.944176, length = 59
# [Episode   97] total reward = -75.525131, length = 1600
# [Episode   98] total reward = -165.883286, length = 1387
# [Episode   99] total reward = -83.149078, length = 1600
# [Episode  100] total reward = -112.930832, length = 65
# [Episode  101] total reward = -67.672745, length = 1600
# [Episode  102] total reward = -112.951332, length = 70
# [Episode  103] total reward = -107.716408, length = 80
# [Episode  104] total reward = -119.878952, length = 119
# [Episode  105] total reward = -72.269989, length = 1600
# [Episode  106] total reward = -105.923431, length = 46
# [Episode  107] total reward = -66.676483, length = 1600
# [Episode  108] total reward = -109.362381, length = 171
# [Episode  109] total reward = -72.160950, length = 1600
# [Episode  110] total reward = -116.274422, length = 99
# [Episode  111] total reward = -104.543869, length = 80
# [Episode  112] total reward = -116.042603, length = 77
# [Episode  113] total reward = -107.949089, length = 70
# [Episode  114] total reward = -122.943497, length = 102
# [Episode  115] total reward = -117.905533, length = 80
# [Episode  116] total reward = -111.089905, length = 64
# [Episode  117] total reward = -107.793488, length = 95
# [Episode  118] total reward = -69.597847, length = 1600
# [Episode  119] total reward = -72.877953, length = 1600
# [Episode  120] total reward = -105.077530, length = 139
# [Episode  121] total reward = -178.922791, length = 1522
# [Episode  122] total reward = -117.257027, length = 64
# [Episode  123] total reward = -121.922531, length = 151
# [Episode  124] total reward = -108.156181, length = 91
# [Episode  125] total reward = -69.921646, length = 1600
# [Episode  126] total reward = -107.929482, length = 47
# [Episode  127] total reward = -112.260498, length = 57
# [Episode  128] total reward = -107.157295, length = 87
# [Episode  129] total reward = -105.023178, length = 63
# [Episode  130] total reward = -85.970390, length = 1600
# [Episode  131] total reward = -107.882942, length = 54
# [Episode  132] total reward = -79.629715, length = 1600
# [Episode  133] total reward = -108.495697, length = 50
# [Episode  134] total reward = -115.838348, length = 60
# [Episode  135] total reward = -120.004349, length = 63
# [Episode  136] total reward = -120.270218, length = 75
# [Episode  137] total reward = -67.869293, length = 1600
# [Episode  138] total reward = -66.567291, length = 1600
# [Episode  139] total reward = -63.536552, length = 1600
# [Episode  140] total reward = -117.868530, length = 91
# [Episode  141] total reward = -68.146362, length = 1600
# [Episode  142] total reward = -59.196625, length = 1600
# [Episode  143] total reward = -60.757919, length = 1600
# [Episode  144] total reward = -57.454674, length = 1600
# [Episode  145] total reward = -121.233505, length = 295
# [Episode  146] total reward = -117.671028, length = 82
# [Episode  147] total reward = -67.798500, length = 1600
# [Episode  148] total reward = -61.571121, length = 1600
# [Episode  149] total reward = -107.236710, length = 84
# [Episode  150] total reward = -115.081833, length = 108
# [Episode  151] total reward = -106.735703, length = 83
# [Episode  152] total reward = -132.941162, length = 990
# [Episode  153] total reward = -68.426102, length = 1600
# [Episode  154] total reward = -115.066666, length = 76
# [Episode  155] total reward = -118.587959, length = 72
# [Episode  156] total reward = -58.299385, length = 1600
# [Episode  157] total reward = -65.139595, length = 1600
# [Episode  158] total reward = -48.937569, length = 1600
# [Episode  159] total reward = -65.443398, length = 1600
# [Episode  160] total reward = -99.156708, length = 118
# [Episode  161] total reward = -107.003769, length = 113
# [Episode  162] total reward = -63.791218, length = 1600
# [Episode  163] total reward = -51.713394, length = 1600
# [Episode  164] total reward = -52.850880, length = 1600
# [Episode  165] total reward = -50.014606, length = 1600
# [Episode  166] total reward = -54.325676, length = 1600
# [Episode  167] total reward = -46.553673, length = 1600
# [Episode  168] total reward = -55.180832, length = 1600
# [Episode  169] total reward = -113.690475, length = 62
# [Episode  170] total reward = -108.372429, length = 77
# [Episode  171] total reward = -53.698486, length = 1600
# [Episode  172] total reward = -55.926453, length = 1600
# [Episode  173] total reward = -55.476139, length = 1600
# [Episode  174] total reward = -110.630447, length = 93
# [Episode  175] total reward = -50.411797, length = 1600
# [Episode  176] total reward = -45.156998, length = 1600
# [Episode  177] total reward = -126.128036, length = 117
# [Episode  178] total reward = -45.000130, length = 1600
# [Episode  179] total reward = -117.108521, length = 798
# [Episode  180] total reward = -101.351402, length = 148
# [Episode  181] total reward = -111.413849, length = 89
# [Episode  182] total reward = -111.675377, length = 95
# [Episode  183] total reward = -117.334999, length = 79
# [Episode  184] total reward = -107.212189, length = 101
# [Episode  185] total reward = -121.525612, length = 95
# [Episode  186] total reward = -109.930122, length = 50
# [Episode  187] total reward = -108.637421, length = 144
# [Episode  188] total reward = -113.138687, length = 68
# [Episode  189] total reward = -127.085266, length = 1472
# [Episode  190] total reward = -36.093628, length = 1600
# [Episode  191] total reward = -106.137421, length = 124
# [Episode  192] total reward = -117.620071, length = 75
# [Episode  193] total reward = -102.080070, length = 354
# [Episode  194] total reward = -105.944565, length = 69
# [Episode  195] total reward = -92.815102, length = 265
# [Episode  196] total reward = -112.526375, length = 98
# [Episode  197] total reward = -104.782578, length = 141
# [Episode  198] total reward = -129.307251, length = 1013
# [Episode  199] total reward = -106.556221, length = 1579
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# [Episode  200] total reward = -25.257645, length = 1600
#
# [  200 /  5000]
# ----------------------------------
# actor loss = -0.016049
# critic loss = 8.293098
# entropy = 5.622211
# mean return = -100.947085
# mean length = 644.03
#
# Saving the model ... Done.
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# [Evaluation] Total reward = -76.798800, length = 1600
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# t: 100%|█████████▉| 1596/1602 [00:04<00:00, 347.52it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/My Drive/ppo_tutorial/video/1689699663.8122597.mp4, 720000 bytes wanted but 0 bytes read,at frame 1601/1602, at time 53.37/53.37 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# [Episode  201] total reward = -125.333191, length = 650
# [Episode  202] total reward = -39.089767, length = 1600
# [Episode  203] total reward = -120.397858, length = 99
# [Episode  204] total reward = -32.595627, length = 1600
# [Episode  205] total reward = -109.428932, length = 45
# [Episode  206] total reward = -120.337280, length = 130
# [Episode  207] total reward = -27.939465, length = 1600
# [Episode  208] total reward = -109.580505, length = 38
# [Episode  209] total reward = -21.250378, length = 1600
# [Episode  210] total reward = -17.750156, length = 1600
# [Episode  211] total reward = -118.095222, length = 85
# [Episode  212] total reward = -12.181019, length = 1600
# [Episode  213] total reward = -108.926231, length = 87
# [Episode  214] total reward = -100.395905, length = 262
# [Episode  215] total reward = -21.908672, length = 1600
# [Episode  216] total reward = -5.949561, length = 1600
# [Episode  217] total reward = -111.452507, length = 223
# [Episode  218] total reward = -115.068123, length = 1458
# [Episode  219] total reward = -60.303299, length = 1600
# [Episode  220] total reward = -8.090472, length = 1600
# [Episode  221] total reward = -30.613937, length = 1600
# [Episode  222] total reward = -108.869102, length = 53
# [Episode  223] total reward = -102.232330, length = 122
# [Episode  224] total reward = -120.146622, length = 585
# [Episode  225] total reward = -16.939877, length = 1600
# [Episode  226] total reward = -17.036079, length = 1600
# [Episode  227] total reward = -5.649739, length = 1600
# [Episode  228] total reward = -31.407494, length = 1600
# [Episode  229] total reward = -110.623260, length = 48
# [Episode  230] total reward = -29.092625, length = 1600
# [Episode  231] total reward = -13.727600, length = 1600
# [Episode  232] total reward = -108.802399, length = 72
# [Episode  233] total reward = -15.493472, length = 1600
# [Episode  234] total reward = 2.932821, length = 1600
# [Episode  235] total reward = -107.910248, length = 47
# [Episode  236] total reward = -5.688728, length = 1600
# [Episode  237] total reward = -110.152794, length = 960
# [Episode  238] total reward = -115.063072, length = 1267
# [Episode  239] total reward = -112.628403, length = 807
# [Episode  240] total reward = -21.870663, length = 1600
# [Episode  241] total reward = -111.439659, length = 73
# [Episode  242] total reward = -107.618317, length = 76
# [Episode  243] total reward = -28.164104, length = 1600
# [Episode  244] total reward = -21.254402, length = 1600
# [Episode  245] total reward = -12.412941, length = 1600
# [Episode  246] total reward = -7.359024, length = 1600
# [Episode  247] total reward = -10.032944, length = 1600
# [Episode  248] total reward = -104.437286, length = 219
# [Episode  249] total reward = -109.645691, length = 803
# [Episode  250] total reward = -13.677743, length = 1600
# [Episode  251] total reward = -2.518017, length = 1600
# [Episode  252] total reward = -105.601753, length = 69
# [Episode  253] total reward = -108.913101, length = 69
# [Episode  254] total reward = 10.219013, length = 1600
# [Episode  255] total reward = -1.101507, length = 1600
# [Episode  256] total reward = -82.642723, length = 1461
# [Episode  257] total reward = 23.440088, length = 1600
# [Episode  258] total reward = -95.167557, length = 1453
# [Episode  259] total reward = -106.548569, length = 70
# [Episode  260] total reward = 29.480892, length = 1600
# [Episode  261] total reward = -101.968170, length = 564
# [Episode  262] total reward = -5.005549, length = 1600
# [Episode  263] total reward = -94.474617, length = 772
# [Episode  264] total reward = 37.978386, length = 1600
# [Episode  265] total reward = -92.540909, length = 917
# [Episode  266] total reward = 30.516830, length = 1600
# [Episode  267] total reward = -107.313881, length = 61
# [Episode  268] total reward = 27.270191, length = 1600
# [Episode  269] total reward = -93.587593, length = 133
# [Episode  270] total reward = 38.082817, length = 1600
# [Episode  271] total reward = -78.621964, length = 741
# [Episode  272] total reward = -80.065392, length = 533
# [Episode  273] total reward = -121.154015, length = 124
# [Episode  274] total reward = -83.716728, length = 1092
# [Episode  275] total reward = 38.884293, length = 1600
# [Episode  276] total reward = 40.607170, length = 1600
# [Episode  277] total reward = -113.454933, length = 67
# [Episode  278] total reward = 68.134842, length = 1600
# [Episode  279] total reward = -110.080826, length = 189
# [Episode  280] total reward = -94.114235, length = 319
# [Episode  281] total reward = -67.267288, length = 630
# [Episode  282] total reward = -112.137558, length = 65
# [Episode  283] total reward = -89.230400, length = 377
# [Episode  284] total reward = -109.271622, length = 64
# [Episode  285] total reward = -83.181046, length = 1116
# [Episode  286] total reward = -94.120224, length = 211
# [Episode  287] total reward = -101.479385, length = 191
# [Episode  288] total reward = -99.185028, length = 61
# [Episode  289] total reward = -65.833054, length = 747
# [Episode  290] total reward = -120.179573, length = 78
# [Episode  291] total reward = -102.921806, length = 105
# [Episode  292] total reward = -115.485970, length = 67
# [Episode  293] total reward = 116.703445, length = 1600
# [Episode  294] total reward = -88.864487, length = 320
# [Episode  295] total reward = -121.926178, length = 106
# [Episode  296] total reward = 53.094604, length = 1600
# [Episode  297] total reward = -103.113281, length = 51
# [Episode  298] total reward = -100.000519, length = 61
# [Episode  299] total reward = -110.795013, length = 57
# [Episode  300] total reward = -58.315899, length = 597
# [Episode  301] total reward = -107.175545, length = 263
# [Episode  302] total reward = 90.988441, length = 1600
# [Episode  303] total reward = 83.328979, length = 1600
# [Episode  304] total reward = 94.028587, length = 1600
# [Episode  305] total reward = 88.858856, length = 1600
# [Episode  306] total reward = 114.944366, length = 1600
# [Episode  307] total reward = -95.201057, length = 238
# [Episode  308] total reward = -105.872932, length = 143
# [Episode  309] total reward = 106.678116, length = 1600
# [Episode  310] total reward = -59.743355, length = 750
# [Episode  311] total reward = -125.851349, length = 94
# [Episode  312] total reward = -107.692375, length = 322
# [Episode  313] total reward = -71.177513, length = 785
# [Episode  314] total reward = 88.275055, length = 1600
# [Episode  315] total reward = -96.952393, length = 89
# [Episode  316] total reward = -114.707169, length = 144
# [Episode  317] total reward = -119.056808, length = 61
# [Episode  318] total reward = -81.044914, length = 740
# [Episode  319] total reward = -103.750610, length = 68
# [Episode  320] total reward = -107.827576, length = 91
# [Episode  321] total reward = -94.838905, length = 521
# [Episode  322] total reward = 102.474411, length = 1600
# [Episode  323] total reward = -107.921143, length = 50
# [Episode  324] total reward = -106.186546, length = 83
# [Episode  325] total reward = -113.320816, length = 108
# [Episode  326] total reward = 100.602005, length = 1600
# [Episode  327] total reward = -57.984100, length = 612
# [Episode  328] total reward = -97.421707, length = 127
# [Episode  329] total reward = -118.973396, length = 73
# [Episode  330] total reward = -67.939125, length = 854
# [Episode  331] total reward = -117.359802, length = 370
# [Episode  332] total reward = -59.181774, length = 704
# [Episode  333] total reward = -103.185379, length = 129
# [Episode  334] total reward = 86.562073, length = 1600
# [Episode  335] total reward = -110.394333, length = 54
# [Episode  336] total reward = -72.513626, length = 631
# [Episode  337] total reward = 109.625221, length = 1600
# [Episode  338] total reward = 100.339798, length = 1600
# [Episode  339] total reward = -115.226135, length = 78
# [Episode  340] total reward = -106.656776, length = 64
# [Episode  341] total reward = 79.591522, length = 1600
# [Episode  342] total reward = -105.631851, length = 109
# [Episode  343] total reward = 108.030281, length = 1600
# [Episode  344] total reward = -110.638023, length = 112
# [Episode  345] total reward = 111.964172, length = 1600
# [Episode  346] total reward = -78.657440, length = 477
# [Episode  347] total reward = 128.490295, length = 1600
# [Episode  348] total reward = -100.195366, length = 224
# [Episode  349] total reward = -28.213486, length = 1329
# [Episode  350] total reward = -111.899254, length = 87
# [Episode  351] total reward = 112.395264, length = 1600
# [Episode  352] total reward = 95.765800, length = 1600
# [Episode  353] total reward = -100.133621, length = 160
# [Episode  354] total reward = -31.909161, length = 1010
# [Episode  355] total reward = -111.138275, length = 105
# [Episode  356] total reward = -107.121147, length = 48
# [Episode  357] total reward = -62.210548, length = 810
# [Episode  358] total reward = 102.377289, length = 1600
# [Episode  359] total reward = 123.171738, length = 1600
# [Episode  360] total reward = -109.628227, length = 54
# [Episode  361] total reward = 2.305351, length = 1318
# [Episode  362] total reward = -103.205902, length = 101
# [Episode  363] total reward = 119.844460, length = 1600
# [Episode  364] total reward = 27.774605, length = 1450
# [Episode  365] total reward = 124.237694, length = 1600
# [Episode  366] total reward = 137.394836, length = 1600
# [Episode  367] total reward = -99.246284, length = 103
# [Episode  368] total reward = -106.051544, length = 227
# [Episode  369] total reward = -93.606766, length = 227
# [Episode  370] total reward = -26.088707, length = 1004
# [Episode  371] total reward = -108.286263, length = 227
# [Episode  372] total reward = -105.614212, length = 172
# [Episode  373] total reward = -103.846130, length = 110
# [Episode  374] total reward = -26.025265, length = 1048
# [Episode  375] total reward = -77.060585, length = 429
# [Episode  376] total reward = -11.899895, length = 1130
# [Episode  377] total reward = -107.296890, length = 109
# [Episode  378] total reward = 24.273170, length = 1395
# [Episode  379] total reward = 6.413639, length = 1279
# [Episode  380] total reward = 127.493271, length = 1600
# [Episode  381] total reward = 115.971024, length = 1600
# [Episode  382] total reward = 126.963074, length = 1600
# [Episode  383] total reward = 157.885437, length = 1600
# [Episode  384] total reward = -85.120972, length = 322
# [Episode  385] total reward = 143.517578, length = 1600
# [Episode  386] total reward = 107.291611, length = 1600
# [Episode  387] total reward = 90.906258, length = 1600
# [Episode  388] total reward = -48.197330, length = 594
# [Episode  389] total reward = -20.216969, length = 871
# [Episode  390] total reward = 154.319580, length = 1600
# [Episode  391] total reward = 175.946594, length = 1600
# [Episode  392] total reward = -6.134930, length = 1101
# [Episode  393] total reward = -45.343502, length = 931
# [Episode  394] total reward = -91.971123, length = 219
# [Episode  395] total reward = 102.046539, length = 1600
# [Episode  396] total reward = -58.448540, length = 743
# [Episode  397] total reward = -58.813511, length = 704
# [Episode  398] total reward = -114.308891, length = 63
# [Episode  399] total reward = -128.116425, length = 103
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# [Episode  400] total reward = 77.420334, length = 1600
#
# [  400 /  5000]
# ----------------------------------
# actor loss = -0.063462
# critic loss = 29.572426
# entropy = 5.644776
# mean return = -37.887783
# mean length = 860.49
#
# Saving the model ... Done.
#
# [Evaluation] Total reward = 192.666888, length = 1600
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# t:  99%|█████████▉| 1593/1602 [00:06<00:00, 214.66it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/My Drive/ppo_tutorial/video/1689699945.1745925.mp4, 720000 bytes wanted but 0 bytes read,at frame 1601/1602, at time 53.37/53.37 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# [Episode  401] total reward = 58.909210, length = 1600
# [Episode  402] total reward = 130.409424, length = 1600
# [Episode  403] total reward = 100.050339, length = 1600
# [Episode  404] total reward = 122.665848, length = 1600
# [Episode  405] total reward = 146.802017, length = 1600
# [Episode  406] total reward = -55.245609, length = 709
# [Episode  407] total reward = 138.501450, length = 1600
# [Episode  408] total reward = -126.349823, length = 135
# [Episode  409] total reward = -105.190079, length = 95
# [Episode  410] total reward = 100.449921, length = 1600
# [Episode  411] total reward = 131.164627, length = 1600
# [Episode  412] total reward = 140.767899, length = 1600
# [Episode  413] total reward = 141.908997, length = 1600
# [Episode  414] total reward = 121.887390, length = 1600
# [Episode  415] total reward = 153.096817, length = 1600
# [Episode  416] total reward = 142.639740, length = 1600
# [Episode  417] total reward = -101.527473, length = 145
# [Episode  418] total reward = -106.822922, length = 65
# [Episode  419] total reward = -98.998650, length = 109
# [Episode  420] total reward = -13.719200, length = 1106
# [Episode  421] total reward = -67.118675, length = 398
# [Episode  422] total reward = -109.510704, length = 53
# [Episode  423] total reward = -40.577362, length = 850
# [Episode  424] total reward = -103.857079, length = 119
# [Episode  425] total reward = -118.786919, length = 109
# [Episode  426] total reward = -114.540970, length = 80
# [Episode  427] total reward = -108.282219, length = 73
# [Episode  428] total reward = -108.022598, length = 46
# [Episode  429] total reward = 147.595062, length = 1600
# [Episode  430] total reward = -123.877922, length = 118
# [Episode  431] total reward = -110.384720, length = 55
# [Episode  432] total reward = -108.481232, length = 57
# [Episode  433] total reward = -117.584396, length = 127
# [Episode  434] total reward = -87.986832, length = 352
# [Episode  435] total reward = -106.959824, length = 63
# [Episode  436] total reward = -18.871346, length = 1014
# [Episode  437] total reward = 103.300079, length = 1600
# [Episode  438] total reward = -102.500793, length = 62
# [Episode  439] total reward = -120.334518, length = 94
# [Episode  440] total reward = -130.405060, length = 78
# [Episode  441] total reward = -76.674255, length = 451
# [Episode  442] total reward = -111.224533, length = 83
# [Episode  443] total reward = -20.681694, length = 739
# [Episode  444] total reward = -122.754211, length = 69
# [Episode  445] total reward = -120.320824, length = 80
# [Episode  446] total reward = -56.043808, length = 518
# [Episode  447] total reward = -127.442947, length = 137
# [Episode  448] total reward = -37.741821, length = 784
# [Episode  449] total reward = -63.939079, length = 982
# [Episode  450] total reward = -119.430038, length = 108
# [Episode  451] total reward = -99.120270, length = 74
# [Episode  452] total reward = -94.146576, length = 162
# [Episode  453] total reward = -96.530006, length = 71
# [Episode  454] total reward = -99.569382, length = 240
# [Episode  455] total reward = -102.895378, length = 109
# [Episode  456] total reward = -109.670181, length = 66
# [Episode  457] total reward = -127.920654, length = 65
# [Episode  458] total reward = -38.522812, length = 823
# [Episode  459] total reward = -99.706055, length = 260
# [Episode  460] total reward = -76.014343, length = 492
# [Episode  461] total reward = -119.436859, length = 74
# [Episode  462] total reward = -85.990372, length = 292
# [Episode  463] total reward = 96.159958, length = 1600
# [Episode  464] total reward = -102.963806, length = 64
# [Episode  465] total reward = -98.852982, length = 85
# [Episode  466] total reward = -66.852127, length = 495
# [Episode  467] total reward = -33.890991, length = 791
# [Episode  468] total reward = -53.335918, length = 677
# [Episode  469] total reward = -109.549759, length = 48
# [Episode  470] total reward = -107.645164, length = 70
# [Episode  471] total reward = -41.957661, length = 1167
# [Episode  472] total reward = -100.778091, length = 65
# [Episode  473] total reward = -68.786270, length = 411
# [Episode  474] total reward = -114.072609, length = 77
# [Episode  475] total reward = -21.207190, length = 966
# [Episode  476] total reward = -71.174652, length = 480
# [Episode  477] total reward = -108.188225, length = 71
# [Episode  478] total reward = -109.602478, length = 52
# [Episode  479] total reward = 22.415268, length = 1358
# [Episode  480] total reward = 124.326096, length = 1600
# [Episode  481] total reward = 5.675270, length = 1483
# [Episode  482] total reward = 105.127136, length = 1600
# [Episode  483] total reward = -107.403877, length = 110
# [Episode  484] total reward = 147.488693, length = 1600
# [Episode  485] total reward = -101.110802, length = 71
# [Episode  486] total reward = -125.131744, length = 94
# [Episode  487] total reward = -42.272549, length = 745
# [Episode  488] total reward = -103.466812, length = 73
# [Episode  489] total reward = -109.292686, length = 63
# [Episode  490] total reward = -58.466949, length = 672
# [Episode  491] total reward = -50.288803, length = 842
# [Episode  492] total reward = 151.570877, length = 1600
# [Episode  493] total reward = 90.458405, length = 1600
# [Episode  494] total reward = -21.055031, length = 1095
# [Episode  495] total reward = -48.318378, length = 630
# [Episode  496] total reward = -123.634415, length = 82
# [Episode  497] total reward = -62.634708, length = 567
# [Episode  498] total reward = -38.802971, length = 1039
# [Episode  499] total reward = 151.234131, length = 1600
# [Episode  500] total reward = 162.320374, length = 1600
# [Episode  501] total reward = -14.053017, length = 1109
# [Episode  502] total reward = 97.042244, length = 1600
# [Episode  503] total reward = -116.782692, length = 79
# [Episode  504] total reward = -115.760696, length = 216
# [Episode  505] total reward = 86.916740, length = 1600
# [Episode  506] total reward = 63.274059, length = 1600
# [Episode  507] total reward = 119.946579, length = 1600
# [Episode  508] total reward = 88.452515, length = 1600
# [Episode  509] total reward = 54.836628, length = 1600
# [Episode  510] total reward = 85.762955, length = 1600
# [Episode  511] total reward = 90.131516, length = 1600
# [Episode  512] total reward = -14.266876, length = 961
# [Episode  513] total reward = 132.913727, length = 1600
# [Episode  514] total reward = -14.023472, length = 1433
# [Episode  515] total reward = -75.583511, length = 658
# [Episode  516] total reward = -109.886185, length = 56
# [Episode  517] total reward = 115.815079, length = 1600
# [Episode  518] total reward = 84.663574, length = 1600
# [Episode  519] total reward = -109.578163, length = 147
# [Episode  520] total reward = 90.171989, length = 1600
# [Episode  521] total reward = 129.919556, length = 1600
# [Episode  522] total reward = 124.960159, length = 1600
# [Episode  523] total reward = -118.157852, length = 91
# [Episode  524] total reward = -109.123337, length = 56
# [Episode  525] total reward = 152.522522, length = 1600
# [Episode  526] total reward = 131.201431, length = 1600
# [Episode  527] total reward = -84.970360, length = 282
# [Episode  528] total reward = -106.636902, length = 67
# [Episode  529] total reward = -107.854790, length = 93
# [Episode  530] total reward = -120.014839, length = 93
# [Episode  531] total reward = -57.498516, length = 817
# [Episode  532] total reward = -24.733318, length = 795
# [Episode  533] total reward = -132.941696, length = 133
# [Episode  534] total reward = -10.281250, length = 996
# [Episode  535] total reward = -110.075844, length = 88
# [Episode  536] total reward = -97.247673, length = 526
# [Episode  537] total reward = -53.294773, length = 795
# [Episode  538] total reward = 128.228989, length = 1600
# [Episode  539] total reward = -125.680962, length = 111
# [Episode  540] total reward = -39.844517, length = 721
# [Episode  541] total reward = 151.086197, length = 1600
# [Episode  542] total reward = -125.281723, length = 128
# [Episode  543] total reward = 153.625931, length = 1600
# [Episode  544] total reward = 139.375793, length = 1600
# [Episode  545] total reward = 155.304993, length = 1600
# [Episode  546] total reward = 108.667213, length = 1600
# [Episode  547] total reward = 131.415314, length = 1600
# [Episode  548] total reward = 126.359695, length = 1600
# [Episode  549] total reward = 127.145905, length = 1600
# [Episode  550] total reward = 140.351105, length = 1600
# [Episode  551] total reward = -5.136459, length = 1073
# [Episode  552] total reward = 181.616180, length = 1600
# [Episode  553] total reward = -108.626175, length = 45
# [Episode  554] total reward = -76.861572, length = 350
# [Episode  555] total reward = 26.073162, length = 1261
# [Episode  556] total reward = 175.159363, length = 1600
# [Episode  557] total reward = -31.362335, length = 958
# [Episode  558] total reward = -48.646851, length = 672
# [Episode  559] total reward = -78.053856, length = 362
# [Episode  560] total reward = -30.936058, length = 749
# [Episode  561] total reward = -126.309959, length = 92
# [Episode  562] total reward = -34.501701, length = 655
# [Episode  563] total reward = 17.347282, length = 1214
# [Episode  564] total reward = 155.822144, length = 1600
# [Episode  565] total reward = -103.395248, length = 121
# [Episode  566] total reward = 0.012619, length = 1228
# [Episode  567] total reward = 142.369019, length = 1600
# [Episode  568] total reward = -112.688026, length = 121
# [Episode  569] total reward = -112.469154, length = 132
# [Episode  570] total reward = -125.150742, length = 122
# [Episode  571] total reward = 147.292068, length = 1600
# [Episode  572] total reward = -35.883636, length = 749
# [Episode  573] total reward = -100.992958, length = 97
# [Episode  574] total reward = 165.519867, length = 1600
# [Episode  575] total reward = -104.023590, length = 118
# [Episode  576] total reward = 0.534946, length = 1094
# [Episode  577] total reward = -109.235542, length = 88
# [Episode  578] total reward = 148.774139, length = 1600
# [Episode  579] total reward = 140.726685, length = 1600
# [Episode  580] total reward = 161.768585, length = 1600
# [Episode  581] total reward = 176.601730, length = 1600
# [Episode  582] total reward = -125.353485, length = 110
# [Episode  583] total reward = -5.462822, length = 1049
# [Episode  584] total reward = 168.850586, length = 1600
# [Episode  585] total reward = -21.969887, length = 915
# [Episode  586] total reward = -8.262127, length = 888
# [Episode  587] total reward = -102.465546, length = 117
# [Episode  588] total reward = -57.506447, length = 527
# [Episode  589] total reward = -79.911110, length = 267
# [Episode  590] total reward = -49.906036, length = 585
# [Episode  591] total reward = 127.228874, length = 1600
# [Episode  592] total reward = -36.733074, length = 835
# [Episode  593] total reward = -110.934074, length = 93
# [Episode  594] total reward = -126.306671, length = 169
# [Episode  595] total reward = 151.315674, length = 1600
# [Episode  596] total reward = 141.559265, length = 1600
# [Episode  597] total reward = 164.505569, length = 1600
# [Episode  598] total reward = -0.410175, length = 1047
# [Episode  599] total reward = 152.640656, length = 1600
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# [Episode  600] total reward = 153.274353, length = 1600
#
# [  600 /  5000]
# ----------------------------------
# actor loss = -0.132086
# critic loss = 30.292105
# entropy = 5.765182
# mean return = -10.147544
# mean length = 805.94
#
# Saving the model ... Done.
#
# [Evaluation] Total reward = 189.284608, length = 1600
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# t:  99%|█████████▉| 1587/1602 [00:06<00:00, 321.59it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/My Drive/ppo_tutorial/video/1689700224.888392.mp4, 720000 bytes wanted but 0 bytes read,at frame 1601/1602, at time 53.37/53.37 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# [Episode  601] total reward = 141.780609, length = 1600
# [Episode  602] total reward = 150.629852, length = 1600
# [Episode  603] total reward = 144.914398, length = 1600
# [Episode  604] total reward = 137.229523, length = 1600
# [Episode  605] total reward = 125.154366, length = 1600
# [Episode  606] total reward = -120.436142, length = 200
# [Episode  607] total reward = 115.069855, length = 1600
# [Episode  608] total reward = 135.380676, length = 1600
# [Episode  609] total reward = -112.417763, length = 83
# [Episode  610] total reward = 127.746475, length = 1600
# [Episode  611] total reward = 142.251572, length = 1600
# [Episode  612] total reward = 129.558960, length = 1600
# [Episode  613] total reward = 121.286392, length = 1600
# [Episode  614] total reward = 141.220642, length = 1600
# [Episode  615] total reward = 154.339630, length = 1600
# [Episode  616] total reward = 148.402527, length = 1600
# [Episode  617] total reward = 148.647980, length = 1600
# [Episode  618] total reward = 143.848251, length = 1600
# [Episode  619] total reward = 135.870880, length = 1600
# [Episode  620] total reward = -103.258682, length = 121
# [Episode  621] total reward = -126.476288, length = 95
# [Episode  622] total reward = -108.395691, length = 93
# [Episode  623] total reward = -78.656624, length = 314
# [Episode  624] total reward = 139.515030, length = 1600
# [Episode  625] total reward = -102.925453, length = 106
# [Episode  626] total reward = 156.453796, length = 1600
# [Episode  627] total reward = 166.914230, length = 1600
# [Episode  628] total reward = 154.792206, length = 1600
# [Episode  629] total reward = 151.136780, length = 1600
# [Episode  630] total reward = 135.730789, length = 1600
# [Episode  631] total reward = 40.151711, length = 1316
# [Episode  632] total reward = 155.410522, length = 1600
# [Episode  633] total reward = 112.708961, length = 1600
# [Episode  634] total reward = 118.669418, length = 1600
# [Episode  635] total reward = 144.324768, length = 1600
# [Episode  636] total reward = 137.425964, length = 1600
# [Episode  637] total reward = -109.770172, length = 66
# [Episode  638] total reward = -125.856079, length = 98
# [Episode  639] total reward = -102.425430, length = 109
# [Episode  640] total reward = 167.156982, length = 1600
# [Episode  641] total reward = -107.627663, length = 60
# [Episode  642] total reward = 164.107300, length = 1600
# [Episode  643] total reward = 162.651031, length = 1600
# [Episode  644] total reward = -67.256241, length = 406
# [Episode  645] total reward = -110.257790, length = 72
# [Episode  646] total reward = 167.268585, length = 1600
# [Episode  647] total reward = -111.175362, length = 44
# [Episode  648] total reward = 147.943970, length = 1600
# [Episode  649] total reward = -99.480751, length = 154
# [Episode  650] total reward = -109.520187, length = 50
# [Episode  651] total reward = 39.289944, length = 1407
# [Episode  652] total reward = -110.509811, length = 145
# [Episode  653] total reward = -57.162399, length = 542
# [Episode  654] total reward = 179.826431, length = 1600
# [Episode  655] total reward = 170.768066, length = 1600
# [Episode  656] total reward = 171.941116, length = 1600
# [Episode  657] total reward = 161.282562, length = 1600
# [Episode  658] total reward = -56.600967, length = 582
# [Episode  659] total reward = 176.406250, length = 1600
# [Episode  660] total reward = 52.915241, length = 1519
# [Episode  661] total reward = 151.596344, length = 1600
# [Episode  662] total reward = 166.490936, length = 1600
# [Episode  663] total reward = -109.953827, length = 215
# [Episode  664] total reward = -101.152168, length = 114
# [Episode  665] total reward = 178.182587, length = 1600
# [Episode  666] total reward = -0.352486, length = 980
# [Episode  667] total reward = -96.585709, length = 143
# [Episode  668] total reward = -107.153221, length = 112
# [Episode  669] total reward = -44.951683, length = 589
# [Episode  670] total reward = -26.102718, length = 844
# [Episode  671] total reward = 15.586048, length = 1433
# [Episode  672] total reward = -90.846947, length = 434
# [Episode  673] total reward = -116.300018, length = 73
# [Episode  674] total reward = -65.015121, length = 571
# [Episode  675] total reward = -29.658817, length = 807
# [Episode  676] total reward = -35.314251, length = 696
# [Episode  677] total reward = -62.026573, length = 551
# [Episode  678] total reward = -18.330967, length = 860
# [Episode  679] total reward = 148.507904, length = 1600
# [Episode  680] total reward = 46.945969, length = 1349
# [Episode  681] total reward = -49.048668, length = 498
# [Episode  682] total reward = 163.727646, length = 1600
# [Episode  683] total reward = -26.077549, length = 706
# [Episode  684] total reward = -93.364075, length = 245
# [Episode  685] total reward = 0.783016, length = 1244
# [Episode  686] total reward = 158.893814, length = 1600
# [Episode  687] total reward = -21.138889, length = 838
# [Episode  688] total reward = -61.206120, length = 467
# [Episode  689] total reward = 157.626709, length = 1600
# [Episode  690] total reward = 172.106781, length = 1600
# [Episode  691] total reward = -42.486248, length = 730
# [Episode  692] total reward = -67.521843, length = 472
# [Episode  693] total reward = 145.334747, length = 1600
# [Episode  694] total reward = -86.189476, length = 234
# [Episode  695] total reward = -108.757492, length = 62
# [Episode  696] total reward = -108.964592, length = 66
# [Episode  697] total reward = -109.666565, length = 63
# [Episode  698] total reward = -110.618629, length = 131
# [Episode  699] total reward = -108.916946, length = 83
# [Episode  700] total reward = -38.072517, length = 927
# [Episode  701] total reward = 145.052612, length = 1600
# [Episode  702] total reward = -106.095802, length = 80
# [Episode  703] total reward = 140.169418, length = 1600
# [Episode  704] total reward = 162.591141, length = 1600
# [Episode  705] total reward = -96.891243, length = 133
# [Episode  706] total reward = -108.453926, length = 67
# [Episode  707] total reward = 175.772644, length = 1600
# [Episode  708] total reward = 152.353760, length = 1600
# [Episode  709] total reward = -50.773952, length = 737
# [Episode  710] total reward = -67.232468, length = 587
# [Episode  711] total reward = -107.734978, length = 58
# [Episode  712] total reward = 160.639069, length = 1600
# [Episode  713] total reward = -119.458107, length = 87
# [Episode  714] total reward = 141.012619, length = 1600
# [Episode  715] total reward = 3.553806, length = 1229
# [Episode  716] total reward = -109.905266, length = 58
# [Episode  717] total reward = -74.522591, length = 326
# [Episode  718] total reward = -93.401726, length = 166
# [Episode  719] total reward = -107.297394, length = 59
# [Episode  720] total reward = 135.769104, length = 1600
# [Episode  721] total reward = 161.049591, length = 1600
# [Episode  722] total reward = -97.524239, length = 275
# [Episode  723] total reward = -72.597847, length = 538
# [Episode  724] total reward = 150.049500, length = 1600
# ...
# [Episode 4742] total reward = 203.114197, length = 1492
# [Episode 4743] total reward = 207.333359, length = 1450
# [Episode 4744] total reward = 210.364334, length = 1396
# [Episode 4745] total reward = 208.990234, length = 1430
# [Episode 4746] total reward = 210.369324, length = 1429
# [Episode 4747] total reward = 208.380264, length = 1433
# [Episode 4748] total reward = -91.999695, length = 224
# [Episode 4749] total reward = -33.856483, length = 554
# [Episode 4750] total reward = 208.338074, length = 1442
# [Episode 4751] total reward = 69.508530, length = 1111
# [Episode 4752] total reward = 214.780106, length = 1386
# [Episode 4753] total reward = 207.319077, length = 1436
# [Episode 4754] total reward = 210.303925, length = 1424
# [Episode 4755] total reward = 211.242737, length = 1403
# [Episode 4756] total reward = -61.549530, length = 650
# [Episode 4757] total reward = 39.896862, length = 1013
# [Episode 4758] total reward = 76.046890, length = 1230
# [Episode 4759] total reward = 201.738586, length = 1485
# [Episode 4760] total reward = 197.709885, length = 1543
# [Episode 4761] total reward = 196.987274, length = 1548
# [Episode 4762] total reward = 55.928505, length = 1345
# [Episode 4763] total reward = 207.091644, length = 1436
# [Episode 4764] total reward = 194.935394, length = 1535
# [Episode 4765] total reward = 211.019470, length = 1406
# [Episode 4766] total reward = 209.023468, length = 1438
# [Episode 4767] total reward = 207.320435, length = 1448
# [Episode 4768] total reward = 215.215118, length = 1366
# [Episode 4769] total reward = 207.953918, length = 1447
# [Episode 4770] total reward = 202.306000, length = 1483
# [Episode 4771] total reward = 221.881027, length = 1318
# [Episode 4772] total reward = -41.107658, length = 469
# [Episode 4773] total reward = 212.891479, length = 1388
# [Episode 4774] total reward = 214.714966, length = 1368
# [Episode 4775] total reward = 9.896732, length = 854
# [Episode 4776] total reward = 218.457077, length = 1350
# [Episode 4777] total reward = 221.260559, length = 1325
# [Episode 4778] total reward = 25.692734, length = 789
# [Episode 4779] total reward = 210.128082, length = 1423
# [Episode 4780] total reward = -15.975349, length = 664
# [Episode 4781] total reward = 215.653793, length = 1377
# [Episode 4782] total reward = -51.969200, length = 401
# [Episode 4783] total reward = 68.260971, length = 1170
# [Episode 4784] total reward = 207.076920, length = 1453
# [Episode 4785] total reward = 218.724731, length = 1338
# [Episode 4786] total reward = 210.229950, length = 1429
# [Episode 4787] total reward = 6.962151, length = 712
# [Episode 4788] total reward = 212.390198, length = 1385
# [Episode 4789] total reward = -43.548721, length = 525
# [Episode 4790] total reward = -20.016121, length = 593
# [Episode 4791] total reward = -39.975067, length = 582
# [Episode 4792] total reward = 208.809601, length = 1432
# [Episode 4793] total reward = 5.095963, length = 829
# [Episode 4794] total reward = 219.104645, length = 1336
# [Episode 4795] total reward = 225.174988, length = 1265
# [Episode 4796] total reward = 67.653122, length = 1174
# [Episode 4797] total reward = 210.992035, length = 1414
# [Episode 4798] total reward = 64.643784, length = 1062
# [Episode 4799] total reward = -13.987190, length = 543
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# [Episode 4800] total reward = 211.615295, length = 1401
#
# [ 4800 /  5000]
# ----------------------------------
# actor loss = 0.068177
# critic loss = 34.540314
# entropy = 10.660034
# mean return = 134.739448
# mean length = 1229.86
#
# Saving the model ... Done.
#
# [Evaluation] Total reward = -79.423875, length = 252
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# [Episode 4801] total reward = 47.018066, length = 962
# [Episode 4802] total reward = 217.801071, length = 1331
# [Episode 4803] total reward = -24.949982, length = 887
# [Episode 4804] total reward = 37.475883, length = 953
# [Episode 4805] total reward = -29.852745, length = 630
# [Episode 4806] total reward = 78.999680, length = 1223
# [Episode 4807] total reward = -4.841831, length = 687
# [Episode 4808] total reward = 211.722717, length = 1411
# [Episode 4809] total reward = 210.600739, length = 1409
# [Episode 4810] total reward = 210.891754, length = 1424
# [Episode 4811] total reward = 201.300507, length = 1517
# [Episode 4812] total reward = 201.715729, length = 1491
# [Episode 4813] total reward = 211.887405, length = 1411
# [Episode 4814] total reward = 210.868759, length = 1415
# [Episode 4815] total reward = 210.244019, length = 1419
# [Episode 4816] total reward = -38.320621, length = 590
# [Episode 4817] total reward = 207.826080, length = 1447
# [Episode 4818] total reward = 204.133057, length = 1473
# [Episode 4819] total reward = 212.015350, length = 1401
# [Episode 4820] total reward = 215.420853, length = 1377
# [Episode 4821] total reward = 210.364441, length = 1429
# [Episode 4822] total reward = 212.026733, length = 1393
# [Episode 4823] total reward = 29.223400, length = 928
# [Episode 4824] total reward = 203.778442, length = 1469
# [Episode 4825] total reward = 208.687103, length = 1425
# [Episode 4826] total reward = -36.793182, length = 573
# [Episode 4827] total reward = 211.882019, length = 1408
# [Episode 4828] total reward = 204.571869, length = 1474
# [Episode 4829] total reward = 213.264099, length = 1391
# [Episode 4830] total reward = 203.186905, length = 1479
# [Episode 4831] total reward = 200.728271, length = 1513
# [Episode 4832] total reward = 204.762344, length = 1462
# [Episode 4833] total reward = 204.144104, length = 1484
# [Episode 4834] total reward = 209.268494, length = 1432
# [Episode 4835] total reward = 207.413696, length = 1450
# [Episode 4836] total reward = 201.460876, length = 1501
# [Episode 4837] total reward = 215.208130, length = 1375
# [Episode 4838] total reward = 1.544487, length = 828
# [Episode 4839] total reward = 208.279083, length = 1440
# [Episode 4840] total reward = 205.180908, length = 1472
# [Episode 4841] total reward = 55.864048, length = 1543
# [Episode 4842] total reward = 213.601776, length = 1385
# [Episode 4843] total reward = 214.076447, length = 1392
# [Episode 4844] total reward = 212.612091, length = 1408
# [Episode 4845] total reward = 212.088577, length = 1413
# [Episode 4846] total reward = 217.221588, length = 1347
# [Episode 4847] total reward = 205.412308, length = 1458
# [Episode 4848] total reward = 215.080246, length = 1372
# [Episode 4849] total reward = 215.270920, length = 1364
# [Episode 4850] total reward = 215.306839, length = 1376
# [Episode 4851] total reward = -90.615349, length = 200
# [Episode 4852] total reward = 202.864365, length = 1495
# [Episode 4853] total reward = 89.189095, length = 1321
# [Episode 4854] total reward = 212.878815, length = 1393
# [Episode 4855] total reward = -89.277077, length = 263
# [Episode 4856] total reward = -22.169094, length = 606
# [Episode 4857] total reward = -45.437107, length = 456
# [Episode 4858] total reward = 218.803345, length = 1319
# [Episode 4859] total reward = -51.776173, length = 629
# [Episode 4860] total reward = -41.038052, length = 458
# [Episode 4861] total reward = -61.491444, length = 411
# [Episode 4862] total reward = 16.821686, length = 841
# [Episode 4863] total reward = 217.914185, length = 1342
# [Episode 4864] total reward = 83.191940, length = 1221
# [Episode 4865] total reward = 214.420593, length = 1367
# [Episode 4866] total reward = -43.882027, length = 466
# [Episode 4867] total reward = -70.645699, length = 297
# [Episode 4868] total reward = 215.377167, length = 1361
# [Episode 4869] total reward = 209.927917, length = 1419
# [Episode 4870] total reward = 212.187225, length = 1390
# [Episode 4871] total reward = 208.209518, length = 1434
# [Episode 4872] total reward = 210.319580, length = 1413
# [Episode 4873] total reward = 206.788757, length = 1449
# [Episode 4874] total reward = 207.714233, length = 1447
# [Episode 4875] total reward = 205.877380, length = 1453
# [Episode 4876] total reward = 214.429184, length = 1373
# [Episode 4877] total reward = 37.462296, length = 943
# [Episode 4878] total reward = 76.854141, length = 1310
# [Episode 4879] total reward = 201.141388, length = 1499
# [Episode 4880] total reward = 204.917419, length = 1449
# [Episode 4881] total reward = 199.750320, length = 1513
# [Episode 4882] total reward = 208.894058, length = 1425
# [Episode 4883] total reward = 206.687683, length = 1449
# [Episode 4884] total reward = 196.156860, length = 1553
# [Episode 4885] total reward = 213.467010, length = 1366
# [Episode 4886] total reward = 200.102753, length = 1507
# [Episode 4887] total reward = 200.860703, length = 1509
# [Episode 4888] total reward = 205.028168, length = 1461
# [Episode 4889] total reward = 207.020981, length = 1437
# [Episode 4890] total reward = 203.407166, length = 1471
# [Episode 4891] total reward = 209.830048, length = 1418
# [Episode 4892] total reward = 209.172867, length = 1427
# [Episode 4893] total reward = 203.138016, length = 1471
# [Episode 4894] total reward = 205.381165, length = 1456
# [Episode 4895] total reward = 185.443298, length = 1600
# [Episode 4896] total reward = 206.502502, length = 1443
# [Episode 4897] total reward = 204.628571, length = 1456
# [Episode 4898] total reward = 202.791626, length = 1487
# [Episode 4899] total reward = 209.897766, length = 1410
# [Episode 4900] total reward = 53.308193, length = 1105
# [Episode 4901] total reward = 62.068890, length = 1319
# [Episode 4902] total reward = 215.388397, length = 1368
# [Episode 4903] total reward = -32.500809, length = 553
# [Episode 4904] total reward = 95.063934, length = 1362
# [Episode 4905] total reward = 208.052032, length = 1433
# [Episode 4906] total reward = 203.633209, length = 1474
# [Episode 4907] total reward = 203.261322, length = 1459
# [Episode 4908] total reward = 207.147675, length = 1435
# [Episode 4909] total reward = 208.762695, length = 1433
# [Episode 4910] total reward = 219.472763, length = 1332
# [Episode 4911] total reward = 205.118774, length = 1451
# [Episode 4912] total reward = 211.555542, length = 1401
# [Episode 4913] total reward = 214.917664, length = 1380
# [Episode 4914] total reward = 211.104996, length = 1414
# [Episode 4915] total reward = -5.631393, length = 789
# [Episode 4916] total reward = 81.738419, length = 1191
# [Episode 4917] total reward = 200.456238, length = 1494
# [Episode 4918] total reward = -16.617821, length = 676
# [Episode 4919] total reward = 213.148010, length = 1396
# [Episode 4920] total reward = -82.951172, length = 187
# [Episode 4921] total reward = -52.266998, length = 464
# [Episode 4922] total reward = 206.865326, length = 1448
# [Episode 4923] total reward = -79.094322, length = 399
# [Episode 4924] total reward = 203.303391, length = 1466
# [Episode 4925] total reward = 200.898895, length = 1505
# [Episode 4926] total reward = 204.402206, length = 1463
# [Episode 4927] total reward = -24.772594, length = 591
# [Episode 4928] total reward = 209.521149, length = 1430
# [Episode 4929] total reward = 213.038605, length = 1385
# [Episode 4930] total reward = 207.006516, length = 1443
# [Episode 4931] total reward = 207.144623, length = 1442
# [Episode 4932] total reward = 214.482635, length = 1368
# [Episode 4933] total reward = 207.269531, length = 1448
# [Episode 4934] total reward = 209.696625, length = 1421
# [Episode 4935] total reward = 219.976685, length = 1322
# [Episode 4936] total reward = 212.760193, length = 1398
# [Episode 4937] total reward = 202.109863, length = 1484
# [Episode 4938] total reward = 216.738052, length = 1347
# [Episode 4939] total reward = 43.726700, length = 1051
# [Episode 4940] total reward = 18.475170, length = 900
# [Episode 4941] total reward = 216.471863, length = 1367
# [Episode 4942] total reward = -46.606697, length = 415
# [Episode 4943] total reward = 85.013535, length = 1159
# [Episode 4944] total reward = 211.327896, length = 1404
# [Episode 4945] total reward = -31.650196, length = 696
# [Episode 4946] total reward = 220.938660, length = 1303
# [Episode 4947] total reward = 213.343414, length = 1375
# [Episode 4948] total reward = 45.747936, length = 1087
# [Episode 4949] total reward = 42.764839, length = 954
# [Episode 4950] total reward = 49.672821, length = 1023
# [Episode 4951] total reward = 217.748779, length = 1346
# [Episode 4952] total reward = -82.670601, length = 209
# [Episode 4953] total reward = -74.530869, length = 231
# [Episode 4954] total reward = -30.237911, length = 512
# [Episode 4955] total reward = -19.728016, length = 678
# [Episode 4956] total reward = 31.253292, length = 922
# [Episode 4957] total reward = -63.468472, length = 412
# [Episode 4958] total reward = 219.704407, length = 1320
# [Episode 4959] total reward = 211.395889, length = 1409
# [Episode 4960] total reward = -75.195900, length = 361
# [Episode 4961] total reward = 214.939011, length = 1361
# [Episode 4962] total reward = -29.235268, length = 609
# [Episode 4963] total reward = 209.397339, length = 1421
# [Episode 4964] total reward = 79.619705, length = 1247
# [Episode 4965] total reward = 207.485413, length = 1446
# [Episode 4966] total reward = 211.464020, length = 1406
# [Episode 4967] total reward = 208.656799, length = 1444
# [Episode 4968] total reward = 195.956848, length = 1543
# [Episode 4969] total reward = 213.796417, length = 1398
# [Episode 4970] total reward = 212.379425, length = 1411
# [Episode 4971] total reward = 201.786697, length = 1502
# [Episode 4972] total reward = 204.430695, length = 1471
# [Episode 4973] total reward = 210.463150, length = 1431
# [Episode 4974] total reward = 16.900414, length = 909
# [Episode 4975] total reward = 197.279358, length = 1532
# [Episode 4976] total reward = 202.644135, length = 1487
# [Episode 4977] total reward = 208.116516, length = 1448
# [Episode 4978] total reward = 204.636963, length = 1475
# [Episode 4979] total reward = 201.232620, length = 1510
# [Episode 4980] total reward = 208.273895, length = 1435
# [Episode 4981] total reward = -8.069130, length = 649
# [Episode 4982] total reward = 211.596603, length = 1396
# [Episode 4983] total reward = 205.155457, length = 1455
# [Episode 4984] total reward = 204.897598, length = 1469
# [Episode 4985] total reward = 210.450562, length = 1427
# [Episode 4986] total reward = 212.852097, length = 1404
# [Episode 4987] total reward = 213.148346, length = 1396
# [Episode 4988] total reward = -16.625114, length = 629
# [Episode 4989] total reward = 207.842102, length = 1450
# [Episode 4990] total reward = 214.277161, length = 1381
# [Episode 4991] total reward = 212.202118, length = 1399
# [Episode 4992] total reward = 7.448788, length = 728
# [Episode 4993] total reward = 217.443695, length = 1348
# [Episode 4994] total reward = 78.406769, length = 1290
# [Episode 4995] total reward = 212.736053, length = 1387
# [Episode 4996] total reward = 79.336479, length = 1265
# [Episode 4997] total reward = -78.484100, length = 346
# [Episode 4998] total reward = 211.503632, length = 1401
# [Episode 4999] total reward = -34.934120, length = 602

# %% [markdown]
# ### 5.3 Load the Model and Play

# %%
save_dir = project_root + '/save'
model_path = os.path.join(save_dir, "model.pt")

if os.path.exists(model_path):
    print("Loading the model ... ", end="")
    checkpoint = torch.load(model_path)
    policy_net.load_state_dict(checkpoint["PolicyNet"])
    print("Done.")
else:
    print('ERROR: No model saved')

play(policy_net)
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# Loading the model ... Done.
# [Evaluation] Total reward = 212.249088, length = 1390
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# t: 100%|█████████▉| 1389/1392 [00:04<00:00, 214.32it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/My Drive/ppo_tutorial/video/1689708334.8074248.mp4, 720000 bytes wanted but 0 bytes read,at frame 1391/1392, at time 46.37/46.37 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
