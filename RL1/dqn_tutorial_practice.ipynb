# %% [markdown]
# # Deep Q Network Tutorial

# %% [markdown]
# ## 1. Environment Preparation
# ### 1.1 Mount drive and set project path.

# %%
from google.colab import drive
drive.mount('/content/drive')

import sys
project_root = '/content/drive/My Drive/DQN_tutorial/'
sys.path.append(project_root)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 1.2 Download Atari ROM.

# %%
! wget http://www.atarimania.com/roms/Roms.rar
! mkdir /content/ROM/
! unzip e /content/Roms.rar /content/ROM/
! python -m atari_py.import_roms /content/ROM/
! pip install "gym[atari, accept-rom-license]"
# Out:
# --2023-07-18 07:36:31--  http://www.atarimania.com/roms/Roms.rar
# Resolving www.atarimania.com (www.atarimania.com)... 195.154.81.199
# Connecting to www.atarimania.com (www.atarimania.com)|195.154.81.199|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19612325 (19M) [application/x-rar-compressed]
# Saving to: ‘Roms.rar’
#
# Roms.rar            100%[===================>]  18.70M   603KB/s    in 32s
#
# 2023-07-18 07:37:04 (593 KB/s) - ‘Roms.rar’ saved [19612325/19612325]
#
# unzip:  cannot find or open e, e.zip or e.ZIP.
# /usr/bin/python3: Error while finding module specification for 'atari_py.import_roms' (ModuleNotFoundError: No module named 'atari_py')
# Requirement already satisfied: gym[accept-rom-license,atari] in /usr/local/lib/python3.10/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym[accept-rom-license,atari]) (1.22.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym[accept-rom-license,atari]) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym[accept-rom-license,atari]) (0.0.8)
# Collecting autorom[accept-rom-license]~=0.4.2 (from gym[accept-rom-license,atari])
#   Downloading AutoROM-0.4.2-py3-none-any.whl (16 kB)
# Collecting ale-py~=0.7.5 (from gym[accept-rom-license,atari])
#   Downloading ale_py-0.7.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 25.6 MB/s eta 0:00:00
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py~=0.7.5->gym[accept-rom-license,atari]) (6.0.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (8.1.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (2.27.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (4.65.0)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari])
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 46.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (3.4)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446660 sha256=b66d215ac2ac08827f3fb993d19eb2eb106d515162de76cb7b520dc2c97639db
#   Stored in directory: /root/.cache/pip/wheels/6b/1b/ef/a43ff1a2f1736d5711faa1ba4c1f61be1131b8899e6a057811
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: ale-py, AutoROM.accept-rom-license, autorom
# Successfully installed AutoROM.accept-rom-license-0.6.1 ale-py-0.7.5 autorom-0.4.2

# %% [markdown]
# ## 2. Pong Game and Wrapper
# ### 2.1 Test the pong environment.

# %%
import gym
import matplotlib.pyplot as plt

env_name = "PongNoFrameskip-v4"
env = gym.make(env_name)

print("environment:", env_name)
print("action space:", env.action_space.n)
print("action:", env.unwrapped.get_action_meanings())
print("observation space:", env.observation_space.shape)

state = env.reset()
action = env.action_space.sample()
print(action)
state_next, reward, done, info = env.step(action)
plt.figure()
plt.imshow(state_next)
# Out:
# environment: PongNoFrameskip-v4
# action space: 6
# action: ['NOOP', 'FIRE', 'RIGHT', 'LEFT', 'RIGHTFIRE', 'LEFTFIRE']
# observation space: (210, 160, 3)
# 0

# %% [markdown]
# ### 2.2 Environment wrapper.

# %%
import numpy as np
from PIL import Image
class PongEnvWrapper(gym.Wrapper):
   def __init__(self, env, k, img_size=(84,84)):
      gym.Wrapper.__init__(self, env)
      self.k = k
      self.img_size = img_size
      obs_shape = env.observation_space.shape
      self.observation_space = gym.spaces.Box(low=0.0, high=1.0, shape=(k, img_size[0], img_size[1]), dtype=np.float32)
   def _preprocess(self, state, th=0.4):
      # TODO(Lab-1): Image processing.
      state = np.array(Image.fromarray(state).resize(self.img_size, Image.BILINEAR))
      state = state.astype(np.float32).mean(2) /255.
      state[state > th] = 1.0
      state[state <= th] = 0.0
      return state
   def reset(self):
      state = self.env.reset()
      state = self._preprocess(state)
      # TODO(Lab-2): Constrct initial stacked frame.
      state = state[np.newaxis, ...].repeat(self.k, axis=0)
      return state
   def step(self, action):
      # TODO(Lab-3): Construct stacked frames.
      state_next = []
      info = []
      reward = 0
      done = False
      for i in range(self.k):
         if not done:
            state_next_f, reward_f, done_f, info_f = self.env.step(action)
            state_next_f = self._preprocess(state_next_f)
            reward += reward_f
            done = done_f
            info.append(info_f)
         state_next.append(state_next_f[np.newaxis, ...])
      state_next = np.concatenate(state_next, 0)
      # state_next, reward, done, info = self.env.step(action)
      # state_next = self._preprocess(state_next)
      # stacked_frames = np.concatenate((self.stacked_frames[1:], state_next[np.newaxis, :, :]), axis=0)
      return state_next, reward, done, info

# %%
# Test Code
env_pong = PongEnvWrapper(env, k=4, img_size=(84,84))
print("observation space:", env_pong.observation_space.shape)

state = env_pong.reset()
action = env_pong.action_space.sample()
state_next, reward, done, info = env_pong.step(action)
print(state_next.shape)
plt.imshow(state_next[0], cmap="gray")
# Out:
# observation space: (4, 84, 84)
# (4, 84, 84)

# %% [markdown]
# ## 3. Reinforcement Learning
# ### 3.1 Convolutional Neural Network

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

class QNet(nn.Module):
    # TODO(Lab-4): Q-Network architecture.
    def __init__(self, input_shape, n_actions):
        super(QNet, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(input_shape[0], 32, kernel_size=8, stride=4),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1),
            nn.ReLU(),
        )

        conv_out_size = self._get_conv_out(input_shape)

        self.fc = nn.Sequential(
            nn.Flatten(),
            nn.Linear(conv_out_size, 512),
            nn.ReLU(),
            nn.Linear(512, n_actions),
        )

    def _get_conv_out(self, shape):
        o = self.conv(torch.zeros(1, *shape))
        return int(np.prod(o.size()))

    def forward(self, x):
        conv_out = self.conv(x)
        out = self.fc(conv_out)
        return out

# %% [markdown]
# ### 3.2 DQN Algorithm

# %%
class DeepQNetwork():
    def __init__(
        self,
        n_actions,
        input_shape,
        qnet,
        device,
        learning_rate = 2e-4,
        reward_decay = 0.99,
        replace_target_iter = 1000,
        memory_size = 10000,
        batch_size = 32,
    ):
        # initialize parameters
        self.n_actions = n_actions
        self.input_shape = input_shape
        self.lr = learning_rate
        self.gamma = reward_decay
        self.replace_target_iter = replace_target_iter
        self.memory_size = memory_size
        self.batch_size = batch_size
        self.device = device
        self.learn_step_counter = 0
        self.init_memory()

        # Network
        self.qnet_eval = qnet(self.input_shape, self.n_actions).to(self.device)
        self.qnet_target = qnet(self.input_shape, self.n_actions).to(self.device)
        self.qnet_target.eval()
        self.optimizer = optim.RMSprop(self.qnet_eval.parameters(), lr=self.lr)

    def choose_action(self, state, epsilon=0):
        state = torch.FloatTensor(state).unsqueeze(0).to(self.device)
        actions_value = self.qnet_eval.forward(state)
        if np.random.uniform() > epsilon:   # greedy
            action = torch.max(actions_value, 1)[1].data.cpu().numpy()[0]
        else:   # random
            action = np.random.randint(0, self.n_actions)
        return action

    def learn(self):
        # TODO(Lab-5): DQN core algorithm.
        if self.learn_step_counter % self.replace_target_iter == 0:
            self.qnet_target.load_state_dict(self.qnet_eval.state_dict())

        # sample batch memory from all memory
        if self.memory_counter > self.memory_size:
            sample_index = np.random.choice(self.memory_size, size=self.batch_size)
        else:
            sample_index = np.random.choice(self.memory_counter, size=self.batch_size)

        b_s = torch.FloatTensor(self.memory["s"][sample_index]).to(self.device)
        b_a = torch.LongTensor(self.memory["a"][sample_index]).to(self.device)
        b_r = torch.FloatTensor(self.memory["r"][sample_index]).to(self.device)
        b_s_ = torch.FloatTensor(self.memory["s_"][sample_index]).to(self.device)
        b_d = torch.FloatTensor(self.memory["done"][sample_index]).to(self.device)

        q_curr_eval = self.qnet_eval(b_s).gather(1, b_a)
        q_next_target = self.qnet_target(b_s_).detach()

        #next_state_values = q_next_target.max(1)[0].view(-1, 1)   # DQN
        q_next_eval = self.qnet_eval(b_s_).detach()
        next_state_values = q_next_target.gather(1, q_next_eval.max(1)[1].unsqueeze(1))   # DDQN

        q_curr_recur = b_r + (1-b_d) * self.gamma * next_state_values
        self.loss = F.smooth_l1_loss(q_curr_eval, q_curr_recur)

        self.optimizer.zero_grad()
        self.loss.backward()
        self.optimizer.step()
        self.learn_step_counter += 1
        return self.loss.detach().cpu().numpy()

    def init_memory(self):
        self.memory = {
            "s": np.zeros((self.memory_size, *self.input_shape)),
            "a": np.zeros((self.memory_size, 1)),
            "r": np.zeros((self.memory_size, 1)),
            "s_": np.zeros((self.memory_size, *self.input_shape)),
            "done": np.zeros((self.memory_size, 1)),
        }

    def store_transition(self, s, a, r, s_, d):
        if not hasattr(self, 'memory_counter'):
            self.memory_counter = 0
        if self.memory_counter <= self.memory_size:
            index = self.memory_counter % self.memory_size
        else:
            index = np.random.randint(self.memory_size)
        self.memory["s"][index] = s
        self.memory["a"][index] = np.array(a).reshape(-1,1)
        self.memory["r"][index] = np.array(r).reshape(-1,1)
        self.memory["s_"][index] = s_
        self.memory["done"][index] = np.array(d).reshape(-1,1)
        self.memory_counter += 1

    def save_load_model(self, op, path="save", fname="qnet.pt"):
        import os
        if not os.path.exists(path):
            os.makedirs(path)
        file_path = os.path.join(path, fname)
        if op == "save":
            torch.save(self.qnet_eval.state_dict(), file_path)
        elif op == "load":
            self.qnet_eval.load_state_dict(torch.load(file_path, map_location=self.device))
            self.qnet_target.load_state_dict(torch.load(file_path, map_location=self.device))

# %%
stack_frames = 4
img_size = (84,84)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

agent = DeepQNetwork(
        n_actions = env.action_space.n,
        input_shape = [stack_frames, *img_size],
        qnet = QNet,
        device = device,
        learning_rate = 2e-4,
        reward_decay = 0.99,
        replace_target_iter = 1000,
        memory_size = 10000,
        batch_size = 32,)

print(agent.qnet_eval)
# Out:
# QNet(
#   (conv): Sequential(
#     (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#     (1): ReLU()
#     (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#     (3): ReLU()
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#     (5): ReLU()
#   )
#   (fc): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=3136, out_features=512, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=512, out_features=6, bias=True)
#   )
# )

# %% [markdown]
# ## 4. Training and testing process.
# ### 4.1 Play the game.

# %%
def play(env, agent, stack_frames, img_size):
    # Reset environment.
    state = env.reset()
    img_buffer = [Image.fromarray(state[0]*255)]
    # Initialize information.
    step = 0
    total_reward = 0

    # One episode.
    while True:
        # Select action.
        action = agent.choose_action(state, 0)

        # Get next stacked state.
        state_next, reward, done, info = env.step(action)
        if step % 2 == 0:
            img_buffer.append(Image.fromarray(state_next[0]*255))
        state = state_next.copy()
        step += 1
        total_reward += reward
        print('\rStep: {:3d} | Reward: {:.3f} / {:.3f}'\
            .format(step, reward, total_reward), end="")

        if done or step>2000:
            print()
            break

    return img_buffer

# %%
import os
def save_gif(img_buffer, fname, gif_path=os.path.join(project_root, "gif")):
    if not os.path.exists(gif_path):
        os.makedirs(gif_path)
    img_buffer[0].save(os.path.join(gif_path, fname), save_all=True, append_images=img_buffer[1:], duration=1, loop=0)

# %%
# Test Code
img_buffer = play(env_pong, agent, stack_frames, img_size)
save_gif(img_buffer, fname="test.gif")

# %% [markdown]
# ### 4.2 Epsilon greedy computation.

# %%
def epsilon_compute(frame_id, epsilon_max=1, epsilon_min=0.05, epsilon_decay=100000):
    return epsilon_min + (epsilon_max - epsilon_min) * np.exp(-frame_id / epsilon_decay)

# %%
# Test Code
frame_ids = np.array(range(400000))
epsilons = epsilon_compute(frame_ids)
plt.plot(epsilons)

# %% [markdown]
# ### 4.3 Training steps.

# %%
def train(env, agent, stack_frames, img_size, save_path="save", max_steps=1000000):
    total_step = 0
    episode = 0
    while True:
        # Reset environment.
        state = env.reset()

        # Initialize information.
        step = 0
        total_reward = 0
        loss = 0

        # One episode.
        while True:
            # TODO(Lab-6): Select action.
            epsilon = epsilon_compute(total_step)
            action = agent.choose_action(state, epsilon)
            # Get next stacked state.
            state_next, reward, done, info = env.step(action)

            # TODO(Lab-7): Train RL model.
            total_reward += reward
            agent.store_transition(state, action, reward, state_next, done)
            if total_step > 4*agent.batch_size:
                loss = agent.learn()
            state = state_next.copy()
            step += 1
            total_step += 1
            total_reward += reward

            if total_step % 100 == 0 or done:
                print('\rEpisode: {:3d} | Step: {:3d} / {:3d} | Reward: {:.3f} / {:.3f} | Loss: {:.3f} | Epsilon: {:.3f}'\
                    .format(episode, step, total_step, reward, total_reward, loss, epsilon), end="")

            if total_step % 10000 == 0:
                print("\nSave Model ...")
                agent.save_load_model(op="save", path=save_path, fname="qnet.pt")
                print("Generate GIF ...")
                img_buffer = play(env, agent, stack_frames, img_size)
                save_gif(img_buffer, "train_" + str(total_step).zfill(6) + ".gif")
                print("Done !!")

            if done or step>2000:
                episode += 1
                print()
                break

        if total_step > max_steps:
            break

# %%
train(env_pong, agent, stack_frames, img_size, save_path=os.path.join(project_root, "save"), max_steps=400000)
# Out:
# Episode:   0 | Step: 871 / 871 | Reward: -1.000 / -42.000 | Loss: 0.001 | Epsilon: 0.992
# Episode:   1 | Step: 960 / 1831 | Reward: -1.000 / -40.000 | Loss: 0.000 | Epsilon: 0.983
# Episode:   2 | Step: 945 / 2776 | Reward: 0.000 / -42.000 | Loss: 0.001 | Epsilon: 0.974
# Episode:  89 | Step: 835 / 110000 | Reward: 0.000 / -16.000 | Loss: 0.001 | Epsilon: 0.366
# Save Model ...
# Generate GIF ...
# Step: 2001 | Reward: 0.000 / -5.000
# Done !!
# Episode:  89 | Step: 1709 / 110874 | Reward: -1.000 / -32.000 | Loss: 0.002 | Epsilon: 0.363
# Episode:  90 | Step: 1729 / 112603 | Reward: 0.000 / -40.000 | Loss: 0.001 | Epsilon: 0.358
# Episode:  91 | Step: 1993 / 114596 | Reward: 0.000 / -30.000 | Loss: 0.001 | Epsilon: 0.352
# Episode:  92 | Step: 1904 / 116500 | Reward: 0.000 / -22.000 | Loss: 0.001 | Epsilon: 0.346
# Episode:  93 | Step: 1903 / 118500 | Reward: 0.000 / -18.000 | Loss: 0.001 | Epsilon: 0.340
# Episode:  94 | Step: 1402 / 120000 | Reward: 0.000 / -32.000 | Loss: 0.001 | Epsilon: 0.336
# Save Model ...
# Generate GIF ...
# Step: 2001 | Reward: 0.000 / -5.000
# Done !!
# Episode:  94 | Step: 1902 / 120500 | Reward: 0.000 / -36.000 | Loss: 0.001 | Epsilon: 0.335
# Episode:  95 | Step: 1708 / 122307 | Reward: -1.000 / -34.000 | Loss: 0.001 | Epsilon: 0.330
# Episode:  96 | Step: 1993 / 124300 | Reward: 0.000 / -18.000 | Loss: 0.001 | Epsilon: 0.324
# Episode:  97 | Step: 1992 / 126300 | Reward: 0.000 / -32.000 | Loss: 0.002 | Epsilon: 0.319
# Episode:  98 | Step: 1991 / 128300 | Reward: 0.000 / -22.000 | Loss: 0.001 | Epsilon: 0.313
# Episode:  99 | Step: 1690 / 130000 | Reward: 0.000 / -20.000 | Loss: 0.000 | Epsilon: 0.309
# Save Model ...
# Generate GIF ...
# Step: 2001 | Reward: 0.000 / -6.000
# Done !!
# Episode:  99 | Step: 1990 / 130300 | Reward: 0.000 / -26.000 | Loss: 0.001 | Epsilon: 0.308
# Episode: 100 | Step: 1989 / 132300 | Reward: 0.000 / -26.000 | Loss: 0.001 | Epsilon: 0.303
# Episode: 101 | Step: 1944 / 134256 | Reward: -1.000 / -30.000 | Loss: 0.001 | Epsilon: 0.298
# Episode: 102 | Step: 1944 / 136200 | Reward: 0.000 / -28.000 | Loss: 0.001 | Epsilon: 0.293
# Episode: 103 | Step: 1943 / 138200 | Reward: 0.000 / -16.000 | Loss: 0.001 | Epsilon: 0.289
# Episode: 104 | Step: 1562 / 139820 | Reward: -1.000 / -38.000 | Loss: 0.000 | Epsilon: 0.285
# Episode: 105 | Step: 180 / 140000 | Reward: 0.000 / -4.000 | Loss: 0.002 | Epsilon: 0.284
# Save Model ...
# Generate GIF ...
# Step: 2001 | Reward: 0.000 / -6.000
# Done !!
# Episode: 105 | Step: 1296 / 141116 | Reward: -1.000 / -12.000 | Loss: 0.000 | Epsilon: 0.282
# Episode: 106 | Step: 1984 / 143100 | Reward: 0.000 / -12.000 | Loss: 0.001 | Epsilon: 0.277
# Episode: 107 | Step: 1983 / 145100 | Reward: 0.000 / -18.000 | Loss: 0.000 | Epsilon: 0.273
# Episode: 108 | Step: 1982 / 147100 | Reward: 0.000 / -24.000 | Loss: 0.001 | Epsilon: 0.268
# Episode: 109 | Step: 1558 / 148677 | Reward: 0.000 / -38.000 | Loss: 0.001 | Epsilon: 0.265
# Episode: 110 | Step: 1323 / 150000 | Reward: 0.000 / -10.000 | Loss: 0.001 | Epsilon: 0.262
# Save Model ...
# Generate GIF ...
# Step: 2001 | Reward: 0.000 / -5.000
# Done !!
# Episode: 110 | Step: 1923 / 150600 | Reward: 0.000 / -8.000 | Loss: 0.001 | Epsilon: 0.261
# Episode: 111 | Step: 1922 / 152600 | Reward: 0.000 / -14.000 | Loss: 0.002 | Epsilon: 0.257
# Episode: 112 | Step: 1921 / 154600 | Reward: 0.000 / -24.000 | Loss: 0.001 | Epsilon: 0.252
# Episode: 113 | Step: 1920 / 156600 | Reward: 0.000 / -8.000 | Loss: 0.000 | Epsilon: 0.248
# Episode: 114 | Step: 1919 / 158600 | Reward: 0.000 / -12.000 | Loss: 0.001 | Epsilon: 0.245
# Episode: 115 | Step: 1318 / 160000 | Reward: 0.000 / -10.000 | Loss: 0.001 | Epsilon: 0.242
# Save Model ...
# Generate GIF ...
# Step: 2001 | Reward: 0.000 / -1.000
# Done !!
# Episode: 115 | Step: 1918 / 160600 | Reward: 0.000 / -20.000 | Loss: 0.001 | Epsilon: 0.241
# Episode: 116 | Step: 1917 / 162600 | Reward: 0.000 / 10.000 | Loss: 0.001 | Epsilon: 0.237
# Episode: 117 | Step: 1916 / 164600 | Reward: 0.000 / -10.000 | Loss: 0.001 | Epsilon: 0.233
# Episode: 118 | Step: 1915 / 166600 | Reward: 0.000 / -6.000 | Loss: 0.001 | Epsilon: 0.230
# Episode: 119 | Step: 1914 / 168600 | Reward: 0.000 / -6.000 | Loss: 0.001 | Epsilon: 0.226
# Episode: 120 | Step: 1313 / 170000 | Reward: 0.000 / -2.000 | Loss: 0.000 | Epsilon: 0.224
# Save Model ...
# Generate GIF ...
# Step: 2001 | Reward: 0.000 / -1.000
# Done !!
# Episode: 120 | Step: 1913 / 170600 | Reward: 0.000 / -4.000 | Loss: 0.002 | Epsilon: 0.223
# Episode: 121 | Step: 1912 / 172600 | Reward: 0.000 / -20.000 | Loss: 0.001 | Epsilon: 0.219
# Episode: 122 | Step: 1911 / 174600 | Reward: 0.000 / -10.000 | Loss: 0.001 | Epsilon: 0.216
# Episode: 123 | Step: 1910 / 176600 | Reward: 0.000 / -24.000 | Loss: 0.000 | Epsilon: 0.212
# Episode: 124 | Step: 1909 / 178600 | Reward: 0.000 / -10.000 | Loss: 0.000 | Epsilon: 0.209
# Episode: 125 | Step: 1308 / 180000 | Reward: 0.000 / 6.000 | Loss: 0.000 | Epsilon: 0.207
# Save Model ...
# Generate GIF ...
# Step: 2001 | Reward: 0.000 / 1.000
# Done !!
# Episode: 125 | Step: 1908 / 180600 | Reward: 0.000 / 2.000 | Loss: 0.000 | Epsilon: 0.206
# Episode: 126 | Step: 1830 / 182523 | Reward: 0.000 / -28.000 | Loss: 0.001 | Epsilon: 0.203
# Episode: 127 | Step: 1977 / 184500 | Reward: 0.000 / -18.000 | Loss: 0.007 | Epsilon: 0.200
# Episode: 128 | Step: 1976 / 186500 | Reward: 0.000 / -10.000 | Loss: 0.001 | Epsilon: 0.197
# Episode: 129 | Step: 1975 / 188500 | Reward: 0.000 / 0.000 | Loss: 0.001 | Epsilon: 0.194
# Episode: 130 | Step: 1474 / 190000 | Reward: 0.000 / 2.000 | Loss: 0.000 | Epsilon: 0.192
# Save Model ...
# Generate GIF ...
# Step: 2001 | Reward: 0.000 / 2.000
# Done !!
# Episode: 130 | Step: 1974 / 190500 | Reward: 0.000 / -2.000 | Loss: 0.000 | Epsilon: 0.191
# Episode: 131 | Step: 1973 / 192500 | Reward: 0.000 / -12.000 | Loss: 0.001 | Epsilon: 0.189
# Episode: 132 | Step: 1972 / 194500 | Reward: 0.000 / -16.000 | Loss: 0.001 | Epsilon: 0.186
# Episode: 133 | Step: 1971 / 196500 | Reward: 0.000 / -20.000 | Loss: 0.001 | Epsilon: 0.183
# Episode: 134 | Step: 1970 / 198500 | Reward: 0.000 / -2.000 | Loss: 0.001 | Epsilon: 0.181
# Episode: 135 | Step: 1469 / 200000 | Reward: 0.000 / -16.000 | Loss: 0.000 | Epsilon: 0.179
# Save Model ...
# Generate GIF ...
# Step: 2001 | Reward: 0.000 / -11.000
# Done !!
# Episode: 135 | Step: 1596 / 200127 | Reward: -1.000 / -20.000 | Loss: 0.000 | Epsilon: 0.178
# Episode: 136 | Step: 1973 / 202100 | Reward: 0.000 / -10.000 | Loss: 0.001 | Epsilon: 0.176
# Episode: 137 | Step: 1972 / 204100 | Reward: 0.000 / -20.000 | Loss: 0.001 | Epsilon: 0.173
# Episode: 138 | Step: 1971 / 206100 | Reward: 0.000 / -12.000 | Loss: 0.001 | Epsilon: 0.171
# Episode: 139 | Step: 1970 / 208100 | Reward: 0.000 / 6.000 | Loss: 0.001 | Epsilon: 0.169
# Episode: 140 | Step: 1869 / 210000 | Reward: 0.000 / -4.000 | Loss: 0.000 | Epsilon: 0.166
# Save Model ...
# Generate GIF ...
# Step: 2001 | Reward: 0.000 / -1.000
# Done !!
# Episode: 140 | Step: 1969 / 210100 | Reward: 0.000 / -2.000 | Loss: 0.001 | Epsilon: 0.166
# Episode: 141 | Step: 1968 / 212100 | Reward: 0.000 / -6.000 | Loss: 0.001 | Epsilon: 0.164
# Episode: 142 | Step: 1967 / 214100 | Reward: 0.000 / -6.000 | Loss: 0.001 | Epsilon: 0.162
# Episode: 143 | Step: 1966 / 216100 | Reward: 0.000 / -16.000 | Loss: 0.001 | Epsilon: 0.159
# Episode: 144 | Step: 1965 / 218100 | Reward: 0.000 / -4.000 | Loss: 0.000 | Epsilon: 0.157
# Episode: 145 | Step: 1864 / 220000 | Reward: 0.000 / 10.000 | Loss: 0.000 | Epsilon: 0.155
# Save Model ...
# Generate GIF ...
# Step: 2001 | Reward: 0.000 / 12.000
# Done !!
# Episode: 145 | Step: 1964 / 220100 | Reward: 0.000 / 12.000 | Loss: 0.001 | Epsilon: 0.155
# Episode: 146 | Step: 1963 / 222100 | Reward: 0.000 / 4.000 | Loss: 0.001 | Epsilon: 0.153
# Episode: 147 | Step: 1962 / 224100 | Reward: 0.000 / 12.000 | Loss: 0.000 | Epsilon: 0.151
# Episode: 148 | Step: 1961 / 226100 | Reward: 0.000 / -2.000 | Loss: 0.000 | Epsilon: 0.149
# Episode: 149 | Step: 1960 / 228100 | Reward: 0.000 / 4.000 | Loss: 0.001 | Epsilon: 0.147
# Episode: 150 | Step: 1859 / 230000 | Reward: 0.000 / -6.000 | Loss: 0.001 | Epsilon: 0.145
# Save Model ...
# Generate GIF ...
# Step: 2001 | Reward: 0.000 / 12.000
# Done !!
# Episode: 150 | Step: 1959 / 230100 | Reward: 0.000 / -4.000 | Loss: 0.000 | Epsilon: 0.145
# Episode: 151 | Step: 1958 / 232100 | Reward: 0.000 / 4.000 | Loss: 0.001 | Epsilon: 0.143
# Episode: 152 | Step: 1957 / 234100 | Reward: 0.000 / 4.000 | Loss: 0.000 | Epsilon: 0.141
# Episode: 153 | Step: 1956 / 236100 | Reward: 0.000 / 10.000 | Loss: 0.001 | Epsilon: 0.140
# Episode: 154 | Step: 1955 / 238100 | Reward: 0.000 / 4.000 | Loss: 0.000 | Epsilon: 0.138
# Episode: 155 | Step: 1854 / 240000 | Reward: 0.000 / -18.000 | Loss: 0.001 | Epsilon: 0.136
# Save Model ...
# Generate GIF ...
# Step: 1988 | Reward: -1.000 / -15.000
# Done !!
# Episode: 155 | Step: 1855 / 240001 | Reward: 0.000 / -18.000 | Loss: 0.001 | Epsilon: 0.136
# Episode: 156 | Step: 1999 / 242000 | Reward: 0.000 / 2.000 | Loss: 0.001 | Epsilon: 0.134
# Episode: 157 | Step: 1998 / 244000 | Reward: 1.000 / 10.000 | Loss: 0.001 | Epsilon: 0.133
# Episode: 158 | Step: 1997 / 246000 | Reward: 0.000 / 16.000 | Loss: 0.000 | Epsilon: 0.131
# Episode: 159 | Step: 1996 / 248000 | Reward: 0.000 / 6.000 | Loss: 0.001 | Epsilon: 0.130
# Episode: 160 | Step: 1995 / 250000 | Reward: 0.000 / 34.000 | Loss: 0.000 | Epsilon: 0.128
# Save Model ...
# Generate GIF ...
# Step: 2001 | Reward: 0.000 / 12.000
# Done !!
#
# Episode: 161 | Step: 1994 / 252000 | Reward: 0.000 / 18.000 | Loss: 0.001 | Epsilon: 0.126
# Episode: 162 | Step: 1993 / 254000 | Reward: 0.000 / 22.000 | Loss: 0.001 | Epsilon: 0.125
# Episode: 163 | Step: 1992 / 256000 | Reward: 0.000 / 8.000 | Loss: 0.001 | Epsilon: 0.123
# Episode: 164 | Step: 1991 / 258000 | Reward: 0.000 / 22.000 | Loss: 0.001 | Epsilon: 0.122
# Episode: 165 | Step: 1990 / 260000 | Reward: 0.000 / -4.000 | Loss: 0.001 | Epsilon: 0.121
# Save Model ...
# Generate GIF ...
# Step: 2001 | Reward: 0.000 / 7.000
# Done !!
#
# Episode: 166 | Step: 1989 / 262000 | Reward: 0.000 / 18.000 | Loss: 0.000 | Epsilon: 0.119
# Episode: 167 | Step: 1988 / 264000 | Reward: 0.000 / 0.000 | Loss: 0.001 | Epsilon: 0.118
# Episode: 168 | Step: 1987 / 266000 | Reward: 0.000 / 20.000 | Loss: 0.001 | Epsilon: 0.116
# Episode: 169 | Step: 1986 / 268000 | Reward: 0.000 / 16.000 | Loss: 0.001 | Epsilon: 0.115
# Episode: 170 | Step: 1985 / 270000 | Reward: 0.000 / 8.000 | Loss: 0.006 | Epsilon: 0.114
# Save Model ...
# Generate GIF ...
# Step: 2001 | Reward: 0.000 / 17.000
# Done !!
#
# Episode: 171 | Step: 1984 / 272000 | Reward: 0.000 / 6.000 | Loss: 0.002 | Epsilon: 0.113
# Episode: 172 | Step: 1983 / 274000 | Reward: 0.000 / 14.000 | Loss: 0.000 | Epsilon: 0.111
# Episode: 173 | Step: 1982 / 276000 | Reward: 0.000 / 14.000 | Loss: 0.000 | Epsilon: 0.110
# Episode: 174 | Step: 1981 / 278000 | Reward: 0.000 / 20.000 | Loss: 0.000 | Epsilon: 0.109
# Episode: 175 | Step: 1980 / 280000 | Reward: 0.000 / 10.000 | Loss: 0.000 | Epsilon: 0.108
# Save Model ...
# Generate GIF ...
# Step: 2001 | Reward: 0.000 / 14.000
# Done !!
#
# Episode: 176 | Step: 1979 / 282000 | Reward: 0.000 / 32.000 | Loss: 0.000 | Epsilon: 0.107
# Episode: 177 | Step: 1978 / 284000 | Reward: 0.000 / 16.000 | Loss: 0.000 | Epsilon: 0.106
# Episode: 178 | Step: 1977 / 286000 | Reward: 0.000 / 22.000 | Loss: 0.000 | Epsilon: 0.104
# Episode: 179 | Step: 1976 / 288000 | Reward: 0.000 / 26.000 | Loss: 0.000 | Epsilon: 0.103
# Episode: 180 | Step: 1975 / 290000 | Reward: 0.000 / 22.000 | Loss: 0.000 | Epsilon: 0.102
# Save Model ...
# Generate GIF ...
# Step: 1745 | Reward: 1.000 / 20.000
# Done !!
# Episode: 180 | Step: 1976 / 290001 | Reward: 0.000 / 22.000 | Loss: 0.000 | Epsilon: 0.102
# Episode: 181 | Step: 1999 / 292000 | Reward: 0.000 / 34.000 | Loss: 0.001 | Epsilon: 0.101
# Episode: 182 | Step: 1998 / 294000 | Reward: 1.000 / 8.000 | Loss: 0.000 | Epsilon: 0.100
# Episode: 183 | Step: 1997 / 296000 | Reward: 0.000 / 26.000 | Loss: 0.000 | Epsilon: 0.099
# Episode: 184 | Step: 1996 / 298000 | Reward: 0.000 / 26.000 | Loss: 0.000 | Epsilon: 0.098
# Episode: 185 | Step: 1995 / 300000 | Reward: 0.000 / 22.000 | Loss: 0.000 | Epsilon: 0.097
# Save Model ...
# Generate GIF ...
# Step: 1847 | Reward: 1.000 / 19.000
# Done !!
# Episode: 185 | Step: 1996 / 300001 | Reward: 0.000 / 22.000 | Loss: 0.000 | Epsilon: 0.097
# Episode: 186 | Step: 1999 / 302000 | Reward: 0.000 / 20.000 | Loss: 0.000 | Epsilon: 0.096
# Episode: 187 | Step: 1998 / 304000 | Reward: 0.000 / 14.000 | Loss: 0.000 | Epsilon: 0.095
# Episode: 188 | Step: 1948 / 305951 | Reward: 1.000 / 40.000 | Loss: 0.001 | Epsilon: 0.095
# Episode: 189 | Step: 1949 / 307900 | Reward: 0.000 / 28.000 | Loss: 0.000 | Epsilon: 0.094
# Episode: 190 | Step: 1746 / 309698 | Reward: 1.000 / 38.000 | Loss: 0.000 | Epsilon: 0.093
# Episode: 191 | Step: 302 / 310000 | Reward: 0.000 / 4.000 | Loss: 0.001 | Epsilon: 0.093
# Save Model ...
# Generate GIF ...
# Step: 1638 | Reward: 1.000 / 21.000
# Done !!
# Episode: 191 | Step: 303 / 310001 | Reward: 0.000 / 4.000 | Loss: 0.001 | Epsilon: 0.093
# Episode: 192 | Step: 1999 / 312000 | Reward: 0.000 / 34.000 | Loss: 0.000 | Epsilon: 0.092
# Episode: 193 | Step: 1998 / 314000 | Reward: 0.000 / 30.000 | Loss: 0.000 | Epsilon: 0.091
# Episode: 194 | Step: 1997 / 316000 | Reward: 0.000 / 32.000 | Loss: 0.000 | Epsilon: 0.090
# Episode: 195 | Step: 1996 / 318000 | Reward: 0.000 / 28.000 | Loss: 0.000 | Epsilon: 0.090
# Episode: 196 | Step: 1995 / 320000 | Reward: 0.000 / 30.000 | Loss: 0.000 | Epsilon: 0.089
# Save Model ...
# Generate GIF ...
# Step: 1856 | Reward: 1.000 / 20.000
# Done !!
# Episode: 196 | Step: 1996 / 320001 | Reward: 0.000 / 30.000 | Loss: 0.000 | Epsilon: 0.089
# Episode: 197 | Step: 1797 / 321798 | Reward: 1.000 / 40.000 | Loss: 0.000 | Epsilon: 0.088
# Episode: 198 | Step: 1902 / 323700 | Reward: 0.000 / 16.000 | Loss: 0.000 | Epsilon: 0.087
# Episode: 199 | Step: 1835 / 325634 | Reward: 0.000 / 38.000 | Loss: 0.000 | Epsilon: 0.087
# Episode: 200 | Step: 1966 / 327600 | Reward: 0.000 / 20.000 | Loss: 0.000 | Epsilon: 0.086
# Episode: 201 | Step: 1965 / 329600 | Reward: 0.000 / 20.000 | Loss: 0.000 | Epsilon: 0.085
# Episode: 202 | Step: 364 / 330000 | Reward: 0.000 / 4.000 | Loss: 0.000 | Epsilon: 0.085
# Save Model ...
# Generate GIF ...
# Step: 1762 | Reward: 1.000 / 18.000
# Done !!
# Episode: 202 | Step: 365 / 330001 | Reward: 0.000 / 4.000 | Loss: 0.000 | Epsilon: 0.085
# Episode: 203 | Step: 1999 / 332000 | Reward: 0.000 / 26.000 | Loss: 0.000 | Epsilon: 0.084
# Episode: 204 | Step: 1998 / 334000 | Reward: 0.000 / -6.000 | Loss: 0.002 | Epsilon: 0.084
# Episode: 205 | Step: 1997 / 336000 | Reward: 0.000 / 20.000 | Loss: 0.001 | Epsilon: 0.083
# Episode: 206 | Step: 1996 / 338000 | Reward: 0.000 / 18.000 | Loss: 0.001 | Epsilon: 0.082
# Episode: 207 | Step: 1995 / 340000 | Reward: 0.000 / 26.000 | Loss: 0.000 | Epsilon: 0.082
# Save Model ...
# Generate GIF ...
# Step: 1642 | Reward: 1.000 / 21.000
# Done !!
# Episode: 207 | Step: 1996 / 340001 | Reward: 0.000 / 26.000 | Loss: 0.000 | Epsilon: 0.082
# Episode: 208 | Step: 1999 / 342000 | Reward: 0.000 / 32.000 | Loss: 0.000 | Epsilon: 0.081
# Episode: 209 | Step: 1998 / 344000 | Reward: 0.000 / 24.000 | Loss: 0.000 | Epsilon: 0.080
# Episode: 210 | Step: 1716 / 345719 | Reward: 1.000 / 40.000 | Loss: 0.000 | Epsilon: 0.080
# Episode: 211 | Step: 1981 / 347700 | Reward: 0.000 / 26.000 | Loss: 0.000 | Epsilon: 0.079
# Episode: 212 | Step: 1980 / 349700 | Reward: 0.000 / 34.000 | Loss: 0.002 | Epsilon: 0.079
# Episode: 213 | Step: 279 / 350000 | Reward: 0.000 / 0.000 | Loss: 0.000 | Epsilon: 0.079
# Save Model ...
# Generate GIF ...
# Step: 1642 | Reward: 1.000 / 21.000
# Done !!
# Episode: 213 | Step: 280 / 350001 | Reward: 0.000 / 0.000 | Loss: 0.000 | Epsilon: 0.079
# Episode: 214 | Step: 1999 / 352000 | Reward: 0.000 / 22.000 | Loss: 0.000 | Epsilon: 0.078
# Episode: 215 | Step: 1939 / 353941 | Reward: 0.000 / 38.000 | Loss: 0.000 | Epsilon: 0.078
# Episode: 216 | Step: 1855 / 355796 | Reward: 1.000 / 38.000 | Loss: 0.000 | Epsilon: 0.077
# Episode: 217 | Step: 1904 / 357700 | Reward: 0.000 / 20.000 | Loss: 0.000 | Epsilon: 0.077
# Episode: 218 | Step: 1903 / 359700 | Reward: 0.000 / 8.000 | Loss: 0.001 | Epsilon: 0.076
# Episode: 219 | Step: 202 / 360000 | Reward: 0.000 / 4.000 | Loss: 0.000 | Epsilon: 0.076
# Save Model ...
# Generate GIF ...
# Step: 1637 | Reward: 1.000 / 21.000
# Done !!
# Episode: 219 | Step: 203 / 360001 | Reward: 0.000 / 4.000 | Loss: 0.000 | Epsilon: 0.076
# Episode: 220 | Step: 1999 / 362000 | Reward: 0.000 / 30.000 | Loss: 0.001 | Epsilon: 0.075
# Episode: 221 | Step: 1973 / 363975 | Reward: 1.000 / 36.000 | Loss: 0.001 | Epsilon: 0.075
# Episode: 222 | Step: 1925 / 365900 | Reward: 0.000 / 24.000 | Loss: 0.000 | Epsilon: 0.074
# Episode: 223 | Step: 1858 / 367834 | Reward: 0.000 / 38.000 | Loss: 0.000 | Epsilon: 0.074
# Episode: 224 | Step: 1966 / 369800 | Reward: 0.000 / 22.000 | Loss: 0.003 | Epsilon: 0.074
# Episode: 225 | Step: 165 / 370000 | Reward: 0.000 / 0.000 | Loss: 0.000 | Epsilon: 0.073
# Save Model ...
# Generate GIF ...
# Step: 1639 | Reward: 1.000 / 21.000
# Done !!
# Episode: 225 | Step: 166 / 370001 | Reward: 0.000 / 0.000 | Loss: 0.000 | Epsilon: 0.073
# Episode: 226 | Step: 1999 / 372000 | Reward: 0.000 / 16.000 | Loss: 0.000 | Epsilon: 0.073
# Episode: 227 | Step: 1731 / 373733 | Reward: 0.000 / 40.000 | Loss: 0.000 | Epsilon: 0.073
# Episode: 228 | Step: 1894 / 375627 | Reward: 1.000 / 38.000 | Loss: 0.000 | Epsilon: 0.072
# Episode: 229 | Step: 1973 / 377600 | Reward: 0.000 / 12.000 | Loss: 0.001 | Epsilon: 0.072
# Episode: 230 | Step: 1859 / 379487 | Reward: 0.000 / 36.000 | Loss: 0.000 | Epsilon: 0.071
# Episode: 231 | Step: 513 / 380000 | Reward: 0.000 / 8.000 | Loss: 0.000 | Epsilon: 0.071
# Save Model ...
# Generate GIF ...
# Step: 1636 | Reward: 1.000 / 21.000
# Done !!
# Episode: 231 | Step: 514 / 380001 | Reward: 0.000 / 8.000 | Loss: 0.000 | Epsilon: 0.071
# Episode: 232 | Step: 1999 / 382000 | Reward: 0.000 / 16.000 | Loss: 0.000 | Epsilon: 0.071
# Episode: 233 | Step: 1998 / 384000 | Reward: 0.000 / 32.000 | Loss: 0.000 | Epsilon: 0.070
# Episode: 234 | Step: 1997 / 386000 | Reward: 0.000 / 30.000 | Loss: 0.000 | Epsilon: 0.070
# Episode: 235 | Step: 1849 / 387853 | Reward: 1.000 / 38.000 | Loss: 0.001 | Epsilon: 0.070
# Episode: 236 | Step: 1947 / 389800 | Reward: 0.000 / 32.000 | Loss: 0.000 | Epsilon: 0.069
# Episode: 237 | Step: 146 / 390000 | Reward: 0.000 / 2.000 | Loss: 0.000 | Epsilon: 0.069
# Save Model ...
# Generate GIF ...
# Step: 1637 | Reward: 1.000 / 21.000
# Done !!
# Episode: 237 | Step: 147 / 390001 | Reward: 0.000 / 2.000 | Loss: 0.000 | Epsilon: 0.069
# Episode: 238 | Step: 1899 / 391900 | Reward: 0.000 / 36.000 | Loss: 0.001 | Epsilon: 0.069
# Episode: 239 | Step: 2000 / 393900 | Reward: 0.000 / 32.000 | Loss: 0.000 | Epsilon: 0.068
# Episode: 240 | Step: 1780 / 395681 | Reward: 1.000 / 36.000 | Loss: 0.000 | Epsilon: 0.068
# Episode: 241 | Step: 1845 / 397526 | Reward: 1.000 / 38.000 | Loss: 0.000 | Epsilon: 0.068
# Episode: 242 | Step: 1974 / 399500 | Reward: 0.000 / 14.000 | Loss: 0.000 | Epsilon: 0.067
# Episode: 243 | Step: 473 / 400000 | Reward: 0.000 / 12.000 | Loss: 0.000 | Epsilon: 0.067
# Save Model ...
# Generate GIF ...
# Step: 1637 | Reward: 1.000 / 21.000
# Done !!
# Episode: 243 | Step: 474 / 400001 | Reward: 0.000 / 12.000 | Loss: 0.000 | Epsilon: 0.067

# %% [markdown]
# ### 4.4 Evaluate the trained model.

# %%
agent.save_load_model(op="load", path=os.path.join(project_root, "save"), fname="qnet.pt")
img_buffer = play(env_pong, agent, stack_frames, img_size)
save_gif(img_buffer, "eval.gif")
# Out:
# Step: 1637 | Reward: 1.000 / 21.000
